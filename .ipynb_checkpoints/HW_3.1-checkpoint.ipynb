# %% [markdown]
# # Homework 3 - Find the perfect place to stay in Texas!
#
# ###### Alessandro Flaborea, Egon Ferri, Melis Kaymaz

# %% [markdown]
# The homework consists in analyzing the text of Airbnb property listings and building a search engine.

# %%
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize, PunktSentenceTokenizer
from nltk.corpus import stopwords
import string
from nltk.stem import PorterStemmer
from nltk import pos_tag, ne_chunk
import nltk
import math
import json
from geopy import distance

# %% [markdown]
# ## Step 2: Create documents

# %% [markdown]
# We want to create a `.tsv` file for each record of the dataset.
# First thing to do is reading the file.

# %%
f = pd.read_csv(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\Airbnb_Texas_Rentals.csv')

f['city'] = list(map(lambda x: x.lower(), f['city']))
f.at[1216, 'latitude'] = 31.498774
f.at[1216, 'longitude'] = -94.345574
f.loc[1216]
geo_city = f.groupby('city').mean().filter(['latitude', 'longitude'])

f['price_rank'] = list(map(lambda x: str(x)[1:], f['average_rate_per_night']))
f
# Out:
#        Unnamed: 0 average_rate_per_night bedrooms_count             city  \
# 0               1                    $27              2           humble
# 1               2                   $149              4      san antonio
# 2               3                    $59              1          houston
# 3               4                    $60              1            bryan
# 4               5                    $75              2       fort worth
# 5               6                   $250              4           conroe
# 6               7                   $129              3      cedar creek
# 7               8                    $25              1       fort worth
# 8               9                   $345              3         rockport
# 9              10                    $72         Studio      san antonio
# 10             11                    $65              1           irving
# 11             12                   $116              1           euless
# 12             13                   $160              2   round mountain
# 13             14                   $110              1      san antonio
# 14             15                   $175              2        kerrville
# 15             16                    $88              2    new braunfels
# 16             17                    $82              2           austin
# 17             18                   $275              1     port aransas
# 18             19                  $1500              4          houston
# 19             20                   $250              2           frisco
# 20             21                  $2999              4             katy
# 21             22                   $350              3  college station
# 22             23                   $165              3             katy
# 23             24                    $65              1             katy
# 24             25                   $100         Studio           denton
# 25             26                    NaN              2      san antonio
# 26             27                    $36              1         richmond
# 27             28                    $65              1             katy
# 28             29                   $110              1           austin
# 29             30                   $650              1          houston
# ...           ...                    ...            ...              ...
# 18229       18230                    $55              2            plano
# 18230       18231                   $300              3     port aransas
# 18231       18232                   $100              1      san antonio
# 18232       18233                   $487              3      san antonio
# 18233       18234                    $40              1           dallas
# 18234       18235                    $45              1          abilene
# 18235       18236                    $82              3      san antonio
# 18236       18237                   $200              2           dallas
# 18237       18238                    $28              3          abilene
# 18238       18239                   $101              1      san antonio
# 18239       18240                    $40              1          abilene
# 18240       18241                   $101              2            plano
# 18241       18242                    $34              1      san antonio
# 18242       18243                    $39              1           dallas
# 18243       18244                    $75              1          tuscola
# 18244       18245                    $90              2          addison
# 18245       18246                    $75              1      san antonio
# 18246       18247                   $299              4      san antonio
# 18247       18248                    $48              1           dallas
# 18248       18249                    $75              1      san antonio
# 18249       18250                    $37              1           dallas
# 18250       18251                    $27              1          abilene
# 18251       18252                   $149              3    alamo heights
# 18252       18253                    $31              1          addison
# 18253       18254                    $38              1      san antonio
# 18254       18255                    $60              1           dallas
# 18255       18256                    $99              2      san antonio
# 18256       18257                    $13              1           dallas
# 18257       18258                    $65              2      san antonio
= open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\doc\doc_' + str(i) + '.tsv', 'w', encoding="utf-8")
#       3     for j in range(10):
#       4         op.write('%s\t' %f.iloc[i, j])
#       5     op.close()
#
# ~\Anaconda3\lib\codecs.py in __init__(self, errors)
#     183     remembers the state of the encoding process between calls to encode().
#     184     """
# --> 185     def __init__(self, errors='strict'):
#     186         """
#     187         Creates an IncrementalEncoder instance.
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 3: Search Engine

# %% [markdown]
# Now, we want to create two different Search Engines that, given as input a query, return the houses that match the query.
#
# As a first common step, we want to preprocess the documents by
#
# 1. Removing stopwords
# 2. Removing punctuation
# 3. Stemming
#
# Then we want to build a file named `vocabulary.txt`, that maps each word to an integer (`term_id`).

# %%
#FUNCTIONS
def preprocess(l):
    final = []
    for i in l:
        if not((ps.stem(i) in stopWords) or (ps.stem(i) in (string.punctuation) )):
            final.append(ps.stem(i))
    return (final)

def vocabularization(vocabulary, final, index):
    for word in final:
        if not(word in vocabulary):
            vocabulary[word] = str(index)
            index = index + 1
    return(vocabulary, index)
stopWords = set(stopwords.words('english'))
ps = PorterStemmer()
string.punctuation = string.punctuation + '–“”’'

# %%
vocabulary= {}
index = 0

for i in range(18259):
    
    op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\doc\doc_' + str(i) + '.tsv', 'r', encoding="utf-8")
    for line in op:
        ou = line.strip().split('\t')
        sentence = ou[5].replace('\\n', ' ').replace('/', ' ').replace('*', ' ').replace('\\r', ' ').replace('\\t', ' ') + ' ' + ou[8].replace('\\n', ' ').replace('/', ' ').replace('*', ' ').replace('\\r', ' ').replace('\\t', ' ')
    op.close()
        
    #preprocessing data deleting stop words, punctuations, ecc.  
    final = preprocess(word_tokenize(sentence))
    
    # IF  word not in vocabulary -> add the word
    vocabulary, index = vocabularization(vocabulary, final, index)
            
op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\vocabulary.txt', 'w', encoding="utf-8")
op.write(json.dumps(vocabulary))
op.close()

# %%
op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\vocabulary.txt', 'r', encoding="utf-8")
vocabulary = json.loads(op.read())

# %% [markdown]
# ### 3.1) Conjunctive query
# At this moment, we narrow out interest on the `description` and `title` of each document. It means that the first Search Engine will evaluate queries with respect to the aforementioned information.

# %% [markdown]
# #### 3.1.1) Creating our index!
#
# We want to create the Inverted Index. It will be a dictionary of this format:
#
# ```
# {
# term_id_1:[document_1, document_2, document_4],
# term_id_2:[document_1, document_3, document_5, document_6],
# ...}
# ```
#
# where _document\_i_ is the *id* of a document that contains the word.
#
# We also want to store it in a separate file and load it in memory when needed.

# %%
inverted_index = {}

for file in range(18259):

    op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\doc\doc_' + str(file) + '.tsv', 'r', encoding="utf-8")
    for line in op:
        ou = line.strip().split('\t')
        sentence = ou[5].replace('\\n', ' ').replace('/', ' ').replace('*', ' ').replace('\\r', ' ').replace('\\t', ' ') + ' ' + ou[8].replace('\\n', ' ').replace('/', ' ').replace('*', ' ').replace('\\r', ' ').replace('\\t', ' ')
    op.close()
 
    
    #preprocessing data deleting stop words, punctuations, ecc.  
    final = preprocess(word_tokenize(sentence))
    
    
    #CREATING INVERTED INDEX
    for word in final:
        index = vocabulary[word]
        if not (index in inverted_index):
            inverted_index[index] = ['doc_' + str(file)]
        elif not('doc_' + str(file) in inverted_index[index]):
            inverted_index[index] = inverted_index[index] + ['doc_' + str(file)]

op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\inverted_index.txt', 'w', encoding="utf-8")
op.write(json.dumps(inverted_index))
op.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-e4df720a11e8> in <module>
#      23
#      24 op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\inverted_index.txt', 'w', encoding="utf-8")
# ---> 25 op.write(json.dumps(inverted_index))
#      26 op.close()
#
# NameError: name 'json' is not defined

# %%
op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\inverted_index.txt', 'r', encoding="utf-8")
inverted_index = json.loads(op.read())

# %% [markdown]
# #### 3.1.2) Execute the query
# Now given a query, that we let the user enter:
# ```
# queen netflix
# ```
# we want that the Search Engine returns a list of documents that contains all the words in the query.

# %% [markdown]
# Query input:

# %%
user_query = input()

#names, l = chunking(sentence) 
    
#preprocessing data deleting stop words, punctuations, ecc.  
final = preprocess(word_tokenize(user_query))
final
# Out:
# a house with swimming pool near to the lake
# ['hous', 'swim', 'pool', 'near', 'lake']

# %% [markdown]
# Traducing the query in our 'language':

# %%
voc = {}
inverted_idx = {}
i=0
for word in final: 
    voc[i]  = vocabulary[word]
    i = i+1
for index in range(i):
    inverted_idx[voc[index]] = inverted_index[voc[index]]

# %% [markdown]
# Finding list of docs that contain all the words in the query and printing them in the format that we want:

# %%
#finding list of docs that contain all the words in the query
docs = []

for i in range(18259):
    doc = 'doc_' + str(i)
    b = True
    for j in voc.values(): 
        b = b and (doc in inverted_idx[j])
    if b:
        docs.append(i)

df = f.filter(items = ['title', 'description', 'city', 'url']).loc[docs]
df.description = list(map(lambda x: x.replace('\\n', ' '), df.description.tolist()))
df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_27547fa8_e90c_11e8_9526_204747782cb8" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >title</th>
#         <th class="col_heading level0 col1" >description</th>
#         <th class="col_heading level0 col2" >city</th>
#         <th class="col_heading level0 col3" >url</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_27547fa8_e90c_11e8_9526_204747782cb8row0_col0" class="data row0 col0" >Comfortable room</td>
#         <td id="T_27547fa8_e90c_11e8_9526_204747782cb8row0_col1" class="data row0 col1" >The house stands near a lake with walking ground . There is a swimming pool in the backyard and I live there with my cat.</td>
#         <td id="T_27547fa8_e90c_11e8_9526_204747782cb8row0_col2" class="data row0 col2" >san antonio</td>
#         <td id="T_27547fa8_e90c_11e8_9526_204747782cb8row0_col3" class="data row0 col3" >https://www.airbnb.com/rooms/12113587?location=Castroville%2C%20TX</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### 3.2) Conjunctive query & Ranking score
# In the new Search Engine, given a query, we want to get the *top-k* (the choice of *k* it's up to you!) documents related to the query. In particular we want:
#
# * Find all the documents that contains all the words in the query (as before...).
# * Sort them by their similarity with the query
# * Return in output *k* documents, or all the documents with non-zero similarity with the query when the results are less than _k_.
#
# To solve this task, we use the *tfIdf* score, and the _Cosine similarity_. Let's see how.

# %% [markdown]
# First thing; we create a new inverted index that contains `tfIdf`s:

# %%
inverted_index_2 = {}

for file in range(18259):

    op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\doc\doc_' + str(file) + '.tsv', 'r', encoding="utf-8")
    for line in op:
        ou = line.strip().split('\t')
        sentence = ou[5].replace('\\n', ' ').replace('/', ' ').replace('*', ' ').replace('\\r', ' ').replace('\\t', ' ') + ' ' + ou[8].replace('\\n', ' ').replace('/', ' ').replace('*', ' ').replace('\\r', ' ').replace('\\t', ' ')
    op.close()
 
    
    #preprocessing data deleting stop words, punctuations, ecc.  
    final = preprocess(word_tokenize(sentence))
    
    
    #CREATING INVERTED INDEX
    for word in final:
        index = vocabulary[word]
        
        tf = final.count(word) / len(final)
        idf = math.log( 18259 / len(inverted_index[vocabulary[word]]))
        
        if not (index in inverted_index_2):
            inverted_index_2[index] = [('doc_' + str(file), tf*idf )]
        elif not(('doc_' + str(file), tf*idf)  in inverted_index_2[index]):
            inverted_index_2[index] = inverted_index_2[index] + [('doc_' + str(file), tf*idf)]


op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\inverted_index_2.txt', 'w', encoding="utf-8")
op.write(json.dumps(inverted_index_2))
op.close()

# %%
del inverted_index_2

# %%
op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\inverted_index_2.txt', 'r', encoding="utf-8")
inverted_index_2 = json.loads(op.read())

# %% [markdown]
# Query input:

# %%
user_query = input()

#preprocessing data deleting stop words, punctuations, ecc.  
final_query = preprocess(word_tokenize(user_query))
final_query
# Out:
# a house with swimming pool near to the lake
# ['hous', 'swim', 'pool', 'near', 'lake']

# %% [markdown]
# Traducing the query in our 'language':

# %%
voc = {}
inverted_query = {}
i=0
for word in final_query: 
    voc[i]  = vocabulary[word]
    i = i+1
for index in range(i):
    inverted_query[voc[index]] = inverted_index_2[voc[index]]

# %% [markdown]
# finding nominator of cosine similarity formula:

# %%
n = {}
index = 0
for i in inverted_query:
    for j in inverted_query[i]:
        if index == 0:
            n[j[0]] = [j[1]]
        elif (not (j[0] in n)):
            n[j[0]] = [0]*index + ([j[1]])
        else:   
            n[j[0]] = n[j[0]] + [0]*(index - len(n[j[0]])) + ([j[1]])
    index = index + 1

for i in n:
    if len(n[i]) < len(final_query) :
        n[i] = n[i] + [0]*(len(final_query)-len(n[i]))

# %% [markdown]
# finding tfidfs of the query:

# %%
tfidf_query = []  
for word in final_query:
    tf_query = final_query.count(word) / len(final_query)
    idf_query = math.log( 18259 / len(inverted_index[vocabulary[word]]))
    tfidf_query.append(tf_query * idf_query)
tfidf_query
# Out:
# [0.28930166218685543,
#  0.6469104060831373,
#  0.4004932603319885,
#  0.43484302877019076,
#  0.4349393910943869]

# %% [markdown]
# finding denominator of our dear formula: norm of the query and norm of docs:

# %%
import numpy
norm_query = numpy.sqrt(sum(list(map(lambda x: x**2, tfidf_query))))

# %%
norm_doc = {}
for i in range(18259):
    doc = 'doc_'+ str(i)
    nomin = 0
    for i in inverted_query:
        for j in inverted_query[i]:
            if j[0] == doc :
                nomin = nomin + j[1]**2
                norm_doc[doc] = nomin
for i in norm_doc:
    norm_doc[i] = numpy.sqrt(norm_doc[i])

# %% [markdown]
# sorting them with haep algorithms:

# %%
daje= []
for i in n:
    st = i
    cos = numpy.dot(tfidf_query, n[st])
    cosine = round(cos / (norm_doc[st]*norm_query), 10)
    #the other formula:
    #import scipy
    #cosine = 1 - scipy.spatial.distance.cosine(tfidf_query, n[st])
    daje.append((cosine, i ))

# %%
import heapq_max
heap_max = []
for i in daje:
    heapq_max.heappush_max(heap_max, i)
heap_max

best_cosine = []
docs = []
for i in range(5):
    cos = heapq_max.heappop_max(heap_max)
    best_cosine.append(cos[0])
    docs.append(int(cos[1][4:]))

# %%
df = f.filter(items = ['title', 'description', 'city', 'url']).loc[docs]
df.description = list(map(lambda x: x.replace('\\n', ' '), df.description.tolist()))
df['ranking'] = best_cosine
df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_679fbb88_e90c_11e8_88f9_204747782cb8" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >title</th>
#         <th class="col_heading level0 col1" >description</th>
#         <th class="col_heading level0 col2" >city</th>
#         <th class="col_heading level0 col3" >url</th>
#         <th class="col_heading level0 col4" >ranking</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row0_col0" class="data row0 col0" >Comfortable room</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row0_col1" class="data row0 col1" >The house stands near a lake with walking ground . There is a swimming pool in the backyard and I live there with my cat.</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row0_col2" class="data row0 col2" >san antonio</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row0_col3" class="data row0 col3" >https://www.airbnb.com/rooms/12113587?location=Castroville%2C%20TX</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row0_col4" class="data row0 col4" >1</td>
#     </tr>    <tr>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row1_col0" class="data row1 col0" >Private room near energy corridor</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row1_col1" class="data row1 col1" >our complex has a lake with a swing seat you can relax on early mornings or evenings. There is a gym and swimming pool as well as wifi. You have access to the kitchen. We are pretty laid back and usually gone all day to work.</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row1_col2" class="data row1 col2" >houston</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row1_col3" class="data row1 col3" >https://www.airbnb.com/rooms/8224234?location=Cinco%20Ranch%2C%20TX</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row1_col4" class="data row1 col4" >0.958952</td>
#     </tr>    <tr>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row2_col0" class="data row2 col0" >24' travel trailer near Lake</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row2_col1" class="data row2 col1" >Located in quaint town of Morgan's Point Resort. Two blocks from lake Belton, tennis courts, and swimming pool. Lots of deer and wild life. Fishing gear, kayak, and boat rental available. Or for fee will tow camper to campground of your choice.</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row2_col2" class="data row2 col2" >belton</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row2_col3" class="data row2 col3" >https://www.airbnb.com/rooms/17238518?location=Belton%2C%20TX</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row2_col4" class="data row2 col4" >0.909968</td>
#     </tr>    <tr>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row3_col0" class="data row3 col0" >24' travel trailer near Lake</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row3_col1" class="data row3 col1" >Located in quaint town of Morgan's Point Resort. Two blocks from lake Belton, tennis courts, and swimming pool. Lots of deer and wild life. Fishing gear, kayak, and boat rental available. Or for fee will tow camper to campground of your choice.</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row3_col2" class="data row3 col2" >belton</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row3_col3" class="data row3 col3" >https://www.airbnb.com/rooms/17238518?location=Bell%20County%2C%20TX</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row3_col4" class="data row3 col4" >0.909968</td>
#     </tr>    <tr>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row4_col0" class="data row4 col0" >Taylor Lake Villa</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row4_col1" class="data row4 col1" >Close to Space Center Houston and NASA Johnson Space Center 5 miles, Kemah Boardwalk 4 miles, and on the waterfront. Enjoy the views, lakefront property, amenities, water activities on site such as a swimming pool, hot tub, kayak, and dock. For couples, solo adventurers, and business travelers. This is a 362 sq ft efficiency apartment attached to a house with a separate entrance and driveway parking with kitchen &amp; laundry. The apartment is located on the second floor. Not for parties.</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row4_col2" class="data row4 col2" >el lago</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row4_col3" class="data row4 col3" >https://www.airbnb.com/rooms/13729915?location=Clear%20Lake%20Shores%2C%20TX</td>
#         <td id="T_679fbb88_e90c_11e8_88f9_204747782cb8row4_col4" class="data row4 col4" >0.904617</td>
#     </tr></tbody>
# </table>

# %%
#FUNCTION FOR CITY PART
geo_city
user_city = input()

# %%
coord_city = (geo_city[geo_city.index == user_city]['latitude'].values[0], geo_city[geo_city.index == user_city]['longitude'].values[0])

# %%
rankings_city = {}
rang  = max(dist.values()) - min(dist.values()) 

for city in geo_city.index:
    coord = (geo_city[geo_city.index == city]['latitude'].values[0], geo_city[geo_city.index == city]['longitude'].values[0])
    rank = 1 - (distance.distance(coord, coord_city).km - min(dist.values())) / rang
    rankings_city[city] = rank
rankings_city
# Out:
# {'abilene': 1.0,
#  'addison': 0.6311349503206789,
#  'alamo heights': 0.5354133277574157,
#  'alba': 0.4844321333591498,
#  'aledo': 0.7321277756982405,
#  'allen': 0.6035238218043392,
#  'alpine': 0.4139947338694395,
#  'alvarado': 0.6874293257187296,
#  'alvin': 0.273748393681821,
#  'amarillo': 0.5172912252219456,
#  'anahuac': 0.24548346156453626,
#  'angleton': 0.2726705659589439,
#  'anna': 0.5869228620981175,
#  'anson': 0.955669679260283,
#  'aransas pass': 0.25619253671808606,
#  'argyle': 0.6580137198285664,
#  'arlington': 0.6697190194927243,
#  'art': 0.7314747309539229,
#  'atascocita': 0.31950193025309337,
#  'athens': 0.5078327973054101,
#  'aubrey': 0.6350960340179839,
#  'austin': 0.5959969369703616,
#  'azle': 0.7173944288755847,
#  'bacliff': 0.25896888885173874,
#  'baird': 0.9546741052649766,
#  'balch springs': 0.6055479512799932,
#  'bandera': 0.5941606755439248,
#  'bastrop': 0.5426708242878385,
#  'bastrop county': 0.562790284203655,
#  'bay city': 0.2791094407871122,
#  'bayside': 0.2849882075031255,
#  'baytown': 0.27850365348524175,
#  'beach city': 0.261630829982466,
#  'beaumont': 0.21288312183052793,
#  'bedford': 0.6694322090919087,
#  'bee cave': 0.6132403246149168,
#  'bellaire': 0.32605260582458306,
#  'bells': 0.5524912641926278,
#  'bellville': 0.428080554577305,
#  'belton': 0.6527487300008692,
#  'ben wheeler': 0.5045056955166514,
#  'benbrook': 0.710399344582308,
#  'bendera': 0.6111947532594386,
#  'berryville': 0.4638204530494324,
#  'bertram': 0.6725009073693317,
#  'blanco': 0.6176559009450333,
#  'blanco county': 0.6317859549867155,
#  'bleiblerville': 0.4519422152213092,
#  'blue mound': 0.6944647210973729,
#  'bluffton': 0.7108662472202829,
#  'boerne': 0.595585017493457,
#  'bolivar': 0.21487309916882058,
#  'bolivar peninsula': 0.2173122013999892,
#  'bolivar pennisula': 0.21927240315141772,
#  'boliver peninsula': 0.21481410101359688,
#  'bowie': 0.710317800351204,
#  'brady': 0.7881000212744047,
#  'brazoria': 0.2683933272996163,
#  'breckenridge': 0.9005138833096169,
#  'brenham': 0.46285731785878603,
#  'briarcliff': 0.6343500628426465,
#  'bridge city': 0.1747157015049754,
#  'bridgeport': 0.7421953803104032,
#  'broaddus': 0.298913266554126,
#  'brookshire': 0.38349786198934943,
#  'brownsville': 0.0,
#  'brownwood': 0.864928550170649,
#  'bryan': 0.49990015932869536,
#  'bryan–college station': 0.496861553583023,
#  'buchanan dam': 0.7037765404529732,
#  'buda': 0.5786814770359594,
#  'buffalo gap': 0.9754905150638067,
#  'bullard': 0.46057113029284735,
#  'bulverde': 0.5749724866027065,
#  'burleson': 0.6964874662077168,
#  'burnet': 0.7009253308504275,
#  'burton': 0.47910236179247734,
#  'caddo': 0.8417141510608299,
#  'caldwell': 0.5155202052219556,
#  'canton': 0.5164964232090736,
#  'canyon': 0.5418786873922875,
#  'canyon lake': 0.5789204010514949,
#  'carmine': 0.48715817891528757,
#  'carrollton': 0.6355906226052,
#  'carthage': 0.3301282133153838,
#  'castroville': 0.5337364372430646,
#  'cat spring': 0.42611025189430185,
#  'cedar creek': 0.5559877492189294,
#  'cedar hill': 0.6490391226918834,
#  'cedar park': 0.6277653054469605,
#  'celina': 0.6073898291878601,
#  'center': 0.29516402930279617,
#  'center point': 0.6194941171158834,
#  'chandler': 0.47509039289381694,
#  'channelview': 0.2981599703934883,
#  'chappell hill': 0.4454055339389994,
#  'cherokee': 0.745719857602497,
#  'chico': 0.7398716375659338,
#  'china': 0.23241595373062263,
#  'china spring': 0.6814062309000863,
#  'chireno': 0.3092687363474875,
#  'cibolo': 0.5397524315238347,
#  'cisco': 0.9080623940555349,
#  'city by the sea': 0.25932290614216946,
#  'city-by-the sea': 0.25939753292395606,
#  'clear lake shores': 0.26747253658312486,
#  'cleburne': 0.7071170402069007,
#  'cleveland': 0.34253708907080094,
#  'clifton': 0.701117912634368,
#  'clyde': 0.9719290708239348,
#  'coldspring': 0.3624083645971816,
#  'coleman': 0.9017562088507114,
#  'college station': 0.4890936776677113,
#  'colleyville': 0.6699675663671787,
#  'columbus': 0.42922608703911436,
#  'comanche': 0.8331172223544089,
#  'comfort': 0.6213002402161697,
#  'concan': 0.5723876859702199,
#  'conroe': 0.3720232440760498,
#  'converse': 0.5310329070659788,
#  'coppell': 0.6487170404960725,
#  'copper canyon': 0.6584574894451333,
#  'copperas cove': 0.6970367389978929,
#  'corinth': 0.6502105780061933,
#  'corpus christi': 0.23054819371615842,
#  'corsicana': 0.5830360489504842,
#  'cottonwood shores': 0.6715458877614734,
#  'crandall': 0.583475873927507,
#  'crawford': 0.6759479141731569,
#  'cresson': 0.7323516472909506,
#  'crosby': 0.3021216306251363,
#  'cross roads': 0.638032742364398,
#  'crowley': 0.704920440545592,
#  'crystal beach': 0.21714479974186351,
#  'dale': 0.5543960350360513,
#  'dallas': 0.6275339750060169,
#  'damon': 0.3142240359646824,
#  'dawson': 0.5935949425770835,
#  'dayton': 0.2859828872288782,
#  'decatur': 0.7093882703846298,
#  'deer park': 0.28779836164001493,
#  'del valle': 0.5703736978650373,
#  'del valley': 0.5690315486055868,
#  'denton': 0.6552444384665281,
#  'desoto': 0.6413172543585217,
#  'devine': 0.5114053066989281,
#  'dickinson': 0.2580097887600781,
#  'dripping springs': 0.6146599746776338,
#  'dublin': 0.8074306876854465,
#  'duncanville': 0.6466932039032309,
#  'eagle lake': 0.42428547124989324,
#  'early': 0.8568838329093259,
#  'east bernard': 0.37770252387354897,
#  'eastland': 0.8749674366873246,
#  'eddy': 0.6497461448690746,
#  'eden': 0.8103661714993797,
#  'edom': 0.4753507131889734,
#  'el campo': 0.35254640893174016,
#  'el lago': 0.27100973863796873,
#  'elgin': 0.5687123088599926,
#  'eliasville': 0.859152963177747,
#  'ellinger': 0.4587522251023689,
#  'emory': 0.5083066349957026,
#  'enchanted oaks': 0.5457048243339065,
#  'ennis': 0.6089345022817985,
#  'euless': 0.6641838102879832,
#  'eustace': 0.5296452079610874,
#  'fair oaks ranch': 0.580219892311868,
#  'fairfield': 0.54124936736455,
#  'fairview': 0.6020220305711736,
#  'farmersville': 0.5579920052712506,
#  'fayetteville': 0.4628547017258433,
#  'flint': 0.4635800764056892,
#  'florence': 0.6590672204198234,
#  'flower mound': 0.6569098144160626,
#  'forney': 0.5917050546142578,
#  'forreston': 0.6393498222373744,
#  'fort bend county': 0.3369224837137882,
#  'fort worth': 0.6993220322806578,
#  'frankston': 0.4631149215746114,
#  'fredericksburg': 0.6635913286133134,
#  'fredonia': 0.76087710964887,
#  'freeport': 0.23634545260036777,
#  'friendswood': 0.28112287858174123,
#  'frisco': 0.6237226413834498,
#  'fulshear': 0.37028746224703846,
#  'fulton': 0.2705715683192601,
#  'galveston': 0.22114573092756384,
#  'galveston county': 0.21657292467025913,
#  'garden ridge': 0.5483996247798998,
#  'garden valley': 0.4774707296056636,
#  'garfield': 0.5704569488767535,
#  'gary city': 0.335104669710243,
#  'gatesville': 0.7072111163714452,
#  'georgetown': 0.6343332676145221,
#  'gilchrist': 0.20650550312482385,
#  'glen rose': 0.7502934399358668,
#  'glenn heights': 0.6427688131661093,
#  'godley': 0.7211987848342042,
#  'goliad': 0.2676181788267915,
#  'goodrich': 0.327922937023299,
#  'gordon': 0.8171424381711339,
#  'graford': 0.8320038015209261,
#  'graham': 0.8390658086532341,
#  'granbury': 0.7513092373966374,
#  'grand prairie': 0.6610769750412304,
#  'grand saline': 0.4978521211489574,
#  'grandview': 0.6905440080775012,
#  'granite shoals': 0.6806108859939328,
#  'grapevine': 0.6613032334500367,
#  'groesbeck': 0.5788870159333865,
#  'groves': 0.1773524650964302,
#  'gun barrel city': 0.5522357302418734,
#  'hallettsville': 0.4203308780175472,
#  'haltom city': 0.6872345240363937,
#  'happy': 0.5501775935732214,
#  'harker heights': 0.6680857555277468,
#  'harlingen': 0.0466122854420189,
#  'haslet': 0.6978758250307352,
#  'hawkins': 0.44555207885377124,
#  'hearne': 0.5347588157015929,
#  'helotes': 0.564055815732587,
#  'hempstead': 0.42246187689350967,
#  'hereford': 0.5176098890760372,
#  'hickory creek': 0.6491753630112507,
#  'highland village': 0.6513017352023259,
#  'highlands': 0.2922709253389538,
#  'hillsboro': 0.6668424551081794,
#  'hockley': 0.40635684634093905,
#  'hondo': 0.5561463578979018,
#  'horseshoe bay': 0.672030255059554,
#  'houston': 0.3177427638762945,
#  'hudson oaks': 0.7395040512988433,
#  'huffman': 0.3172573505244568,
#  'humble': 0.32569174566317494,
#  'hunt': 0.6448392018416049,
#  'hurst': 0.6750743600922965,
#  'hutto': 0.6073643959357851,
#  'industry': 0.45499142698232564,
#  'ingleside': 0.2532837287690929,
#  'ingram': 0.6473533994912551,
#  'irving': 0.6493218548118398,
#  'jacksboro': 0.7529717142012584,
#  'jamaica beach': 0.22984076323611602,
#  'jasper': 0.3312038351977262,
#  'johnson city': 0.6306096451511964,
#  'jonestown': 0.6311145062790274,
#  'joshua': 0.7061291469212987,
#  'junction': 0.7170788248133254,
#  'justin': 0.6823610623259972,
#  'katy': 0.3631090157697049,
#  'kaufman': 0.5695068812132053,
#  'keene': 0.7006976665634622,
#  'keller': 0.6831751699163757,
#  'kemah': 0.2667259259133943,
#  'kemp': 0.5556136012261608,
#  'kendall county': 0.5900973128321916,
#  'kennedale': 0.6806934871990441,
#  'kerens': 0.5526619757501885,
#  'kerrville': 0.6397932667082513,
#  'killeen': 0.680103723397044,
#  'kingsland': 0.6916842999580095,
#  'kingsville': 0.23876865152140359,
#  'kingwood': 0.3268442392639762,
#  'kirby': 0.5293559489878803,
#  'krum': 0.6684026326910042,
#  'kyle': 0.5698952687612435,
#  'la marque': 0.2480855345382469,
#  'la porte': 0.2760716719075963,
#  'lago vista': 0.6332601673436702,
#  'laguna vista': 0.01778010588349932,
#  'lake dallas': 0.6483352329390277,
#  'lake jackson': 0.25954361330344833,
#  'lakehills': 0.5673393070704492,
#  'lakeway': 0.6244851074499227,
#  'lampasas': 0.7242546831915775,
#  'lancaster': 0.6305408425829837,
#  'lantana': 0.6610970222911104,
#  'larue': 0.48952631009736236,
#  'league city': 0.2685753579470369,
#  'leakey': 0.5858855634652196,
#  'leander': 0.6337753763672853,
#  'ledbetter': 0.49539256955631916,
#  'leonard': 0.5529567360334193,
#  'lewisville': 0.6498182598534757,
#  'liberty hill': 0.6563192503442572,
#  'lindale': 0.479772751845139,
#  'little elm': 0.6334953380710876,
#  'live oak': 0.5401531620615125,
#  'livingston': 0.33411092428423816,
#  'llano': 0.7123150854155638,
#  'llano county': 0.7224052584920552,
#  'lockhart': 0.5317415107017357,
#  'lohn': 0.8363781561675283,
#  'los fresnos': 0.019469518475772718,
#  'lucas': 0.5971162356994859,
#  'lumberton': 0.2218388253386656,
#  'mabank': 0.5430463370491092,
#  'magnolia': 0.381132504256394,
#  'malakoff': 0.5361660132671364,
#  'manchaca': 0.5849887235808422,
#  'manor': 0.5852009286187934,
#  'mansfield': 0.6708372034403842,
#  'manvel': 0.29000048859351735,
#  'marble falls': 0.6671744511235842,
#  'marion': 0.5233796088607279,
#  'martindale': 0.5521129119443193,
#  'mason': 0.7354336764925036,
#  'matagorda': 0.26668130411301816,
#  'mcdade': 0.550378963897775,
#  'mcgregor': 0.6793221730551161,
#  'mckinney': 0.6013703350688893,
#  'mcqueeney': 0.5305530063427619,
#  'medina': 0.6100612640335492,
#  'melissa': 0.5898995237568473,
#  'menard': 0.7799192445716122,
#  'meridian': 0.7336141212142993,
#  'merkel': 0.9654330121536,
#  'mertens': 0.6373515913033053,
#  'mexia': 0.5821207833486739,
#  'mico': 0.5650546217691597,
#  'midlothian': 0.6566554907581615,
#  'milam': 0.24013465165099412,
#  'millican': 0.46163444070897597,
#  'mineola': 0.4674990510014563,
#  'missouri city': 0.3348755090734966,
#  'montalba': 0.4933351850463473,
#  'montgomery': 0.4015321242641916,
#  'montgomery county': 0.33228078127798,
#  'morgan': 0.7049549954265311,
#  'mountain home': 0.6595040795916096,
#  'murchison': 0.500396008931862,
#  'nacogdoches': 0.34605764770440484,
#  'natalia': 0.5097907449498562,
#  'navasota': 0.44300581305024067,
#  'nederland': 0.1876131787480766,
#  'needville': 0.31780013330987944,
#  'nemo': 0.7398575616750439,
#  'new braunfels': 0.5497643986415166,
#  'new caney': 0.3365243917150731,
#  'new fairview': 0.6992012592108343,
#  'new ulm': 0.4454137479042295,
#  'new waverly': 0.3944696738200125,
#  'nolanville': 0.6676236563187485,
#  'north padre island corpus christi': 0.2557042695942139,
#  'north richland hills': 0.6791220470882928,
#  'northlake': 0.6787224761339619,
#  'oak point': 0.6405196693381364,
#  'orange': 0.18567113996749784,
#  'ovalo': 0.9559903250710201,
#  'paige': 0.5355992585351517,
#  'palacios': 0.2913310254032949,
#  'palestine': 0.49107056334180754,
#  'palo pinto': 0.8088300868311008,
#  'pasadena': 0.291518050951716,
#  'pearland': 0.2928765374928156,
#  'pflugerville': 0.6041420352829203,
#  'pilot point': 0.6270300210925848,
#  'pipe creek': 0.5875109197862728,
#  'plainview': 0.6409681113365968,
#  'plano': 0.6172677064902254,
#  'point venture': 0.6267806433847871,
#  'pontotoc': 0.7647608499900972,
#  'port aransas': 0.2393435301273309,
#  'port arthur': 0.17538569392285652,
#  'port bolivar': 0.21481916515183808,
#  'port isabel': 0.007855035844544389,
#  'port neches': 0.18403948827590888,
#  'porter': 0.338842310282256,
#  'possum kingdom lake': 0.8233590195953301,
#  'princeton': 0.5813021794421558,
#  'prosper': 0.614024576206122,
#  'quitman': 0.46529900520118017,
#  'rancho viejo': 0.01835369514461971,
#  'red oak': 0.6351490217795783,
#  'red rock': 0.5268828245675234,
#  'richardson': 0.6199829775697918,
#  'richland hills': 0.6829979858832106,
#  'richmond': 0.35068363664795343,
#  'rio frio': 0.5874295522730135,
#  'rio medina': 0.5587671119427888,
#  'river oaks': 0.703765474712069,
#  'riviera': 0.1973217533706738,
#  'riviera beach': 0.19738810227504888,
#  'roanoke': 0.6797957541181125,
#  'rockdale': 0.566685553100995,
#  'rockport': 0.2699721765624047,
#  'rogers': 0.6265982225423132,
#  'rosanky': 0.5225302073869014,
#  'rosenberg': 0.33981682132258817,
#  'rosharon': 0.29150340189212287,
#  'round mountain': 0.6497053298946649,
#  'round rock': 0.6134208774176433,
#  'round top': 0.4750692512130146,
#  'runaway bay': 0.7434051582760781,
#  'sabinal': 0.5723933844072422,
#  'saginaw': 0.6994353214028186,
#  'salado': 0.6461951365006519,
#  'san antonio': 0.5407263198593271,
#  'san augustine': 0.29886458356853485,
#  'san benito': 0.022971004154342167,
#  'san leon': 0.250740435038761,
#  'san marcos': 0.5703932639968097,
#  'san saba': 0.7747779679291849,
#  'sanger': 0.6526784981534399,
#  'santa fe': 0.25446235712636334,
#  'santo': 0.8082409735312674,
#  'sargent': 0.2496777987748635,
#  'savannah': 0.6300154739085958,
#  'schertz': 0.5408327191262483,
#  'scurry': 0.5776779805004341,
#  'seabrook': 0.26934683203955534,
#  'seagoville': 0.6052686655236325,
#  'sealy': 0.4028715314195719,
#  'seguin': 0.5251979631765582,
#  'selma': 0.5434391146090216,
#  'shady shores': 0.6463508581395843,
#  'shenandoah': 0.3648105611854845,
#  'shore acres': 0.2718027396099201,
#  'shoreacres': 0.2740112216241436,
#  'silsbee': 0.23153124263334224,
#  'smithville': 0.5204464303577752,
#  'somerville': 0.49065223855207996,
#  'south houston': 0.2973335772735053,
#  'south padre island': 0.009617493842438707,
#  'southlake': 0.6684929918159083,
#  'spicewood': 0.6364858212384358,
#  'spring': 0.3580813714566795,
#  'spring branch': 0.5797222647215761,
#  'springtown': 0.7267274585365946,
#  'star harbor': 0.5382962228164643,
#  'stephenville': 0.8078224299211445,
#  'streetman': 0.5462370868029254,
#  'sugar land': 0.33531280804176855,
#  'sugarland': 0.3312195275598204,
#  'sunrise beach village': 0.6813944849023326,
#  'sunset': 0.7123889533417382,
#  'sunset valley': 0.5937789376567422,
#  'surfside': 0.23609440891432398,
#  'surfside beach': 0.2361058445604871,
#  'sweeny': 0.28895184277322405,
#  'taft': 0.2815827623996632,
#  'tarpley': 0.5874619621983524,
#  'taylor': 0.6000607561599963,
#  'teague': 0.5493431069129042,
#  'temple': 0.6426349676954095,
#  'terlingua': 0.34109485439862597,
#  'terlingua ranch': 0.3667390953796864,
#  'texas city': 0.24470351475788443,
#  'the colony': 0.6308499128190972,
#  'the hills': 0.6220964363037077,
#  'the woodlands': 0.36722040570487413,
#  'tiki island': 0.23288379331860765,
#  'tomball': 0.3713986423006743,
#  'tool': 0.5529847385446531,
#  'tow': 0.7177207743114,
#  'travis county': 0.6040703290370709,
#  'trinidad': 0.5466465607359272,
#  'trophy club': 0.6723631284044761,
#  'tuscola': 0.9619559967909681,
#  'universal city': 0.5386072403707883,
#  'university park': 0.6280642527037597,
#  'van': 0.487762997440935,
#  'van alstyne': 0.5723981529435571,
#  'venus': 0.6705057400994922,
#  'volente': 0.6288941518929271,
#  'waco': 0.6528076931884204,
#  'waelder': 0.5050002634731081,
#  'waller': 0.4022230960384041,
#  'washington': 0.45245482818003946,
#  'watauga': 0.6824531694527254,
#  'waxahachie': 0.6395911363614002,
#  'weatherford': 0.7461970191445464,
#  'webberville': 0.5761699761619169,
#  'webster': 0.2740530544992642,
#  'weimar': 0.42519719211618634,
#  'west': 0.656260687196719,
#  'west lake hills': 0.600783020970812,
#  'westworth village': 0.7059004036660805,
#  'wharton': 0.3481993482131037,
#  'white settlement': 0.7131887365082312,
#  'whitewright': 0.5636228268733539,
#  'whitney': 0.694579181838396,
#  'willis': 0.39460599292725795,
#  'willow park': 0.7344061530075441,
#  'wills point': 0.5196496908090636,
#  'wimberley': 0.5880610573417411,
#  'winnie': 0.21334827109596277,
#  'winnsboro': 0.44829977583988745,
#  'woodway': 0.6698572272497068,
#  'yantis': 0.47471095050442935,
#  'zephyr': 0.8299309027714413,
#  '诺斯莱克': 0.6810806049284579,
#  '阿纳瓦克': 0.24946400580221006}

# %%
# PRICE FUNCTION

user_price = input()
# Out:
# 50

# %%
#taking the distances between the price of the room and the user price

price_dist=[]
for i in f.price_rank.values:
    try:
        price_dist.append(abs((int(i)) - int(user_price ))  )
    except:
        price_dist.append(-1)
price_dist
# Out:
# [23,
#  99,
#  9,
#  10,
#  25,
#  200,
#  79,
#  25,
#  295,
#  22,
#  15,
#  66,
#  110,
#  60,
#  125,
#  38,
#  32,
#  225,
#  1450,
#  200,
#  2949,
#  300,
#  115,
#  15,
#  50,
#  -1,
#  14,
#  15,
#  60,
#  600,
#  144,
#  25,
#  31,
#  69,
#  175,
#  38,
#  35,
#  55,
#  449,
#  25,
#  15,
#  320,
#  450,
#  15,
#  35,
#  0,
#  67,
#  194,
#  800,
#  2,
#  400,
#  250,
#  157,
#  50,
#  55,
#  31,
#  10,
#  70,
#  9,
#  5,
#  20,
#  149,
#  12,
#  200,
#  5,
#  750,
#  10,
#  100,
#  1033,
#  15,
#  80,
#  28,
#  60,
#  19,
#  65,
#  25,
#  0,
#  75,
#  250,
#  750,
#  750,
#  25,
#  0,
#  15,
#  85,
#  15,
#  5,
#  225,
#  39,
#  150,
#  700,
#  150,
#  2,
#  95,
#  30,
#  10,
#  950,
#  295,
#  600,
#  25,
#  49,
#  50,
#  325,
#  -1,
#  -1,
#  -1,
#  145,
#  295,
#  13,
#  59,
#  10,
#  149,
#  20,
#  5,
#  20,
#  14,
#  139,
#  450,
#  300,
#  150,
#  30,
#  350,
#  115,
#  100,
#  5,
#  0,
#  10,
#  45,
#  285,
#  65,
#  5,
#  11,
#  60,
#  48,
#  125,
#  30,
#  11,
#  25,
#  75,
#  300,
#  24,
#  100,
#  42,
#  91,
#  150,
#  53,
#  9,
#  55,
#  10,
#  140,
#  150,
#  200,
#  10,
#  65,
#  239,
#  718,
#  0,
#  200,
#  205,
#  65,
#  11,
#  450,
#  404,
#  722,
#  100,
#  151,
#  50,
#  -1,
#  90,
#  -1,
#  -1,
#  -1,
#  -1,
#  20,
#  89,
#  10,
#  653,
#  -1,
#  150,
#  -1,
#  -1,
#  -1,
#  30,
#  550,
#  24,
#  8,
#  58,
#  119,
#  40,
#  24,
#  65,
#  275,
#  49,
#  225,
#  412,
#  85,
#  375,
#  27,
#  50,
#  69,
#  24,
#  30,
#  193,
#  139,
#  91,
#  13,
#  79,
#  245,
#  20,
#  159,
#  36,
#  73,
#  5,
#  79,
#  5,
#  275,
#  30,
#  12,
#  360,
#  51,
#  5,
#  8,
#  45,
#  301,
#  300,
#  22,
#  110,
#  5,
#  86,
#  5,
#  200,
#  110,
#  137,
#  49,
#  950,
#  110,
#  125,
#  583,
#  550,
#  200,
#  5,
#  135,
#  215,
#  155,
#  50,
#  143,
#  3,
#  9,
#  200,
#  100,
#  20,
#  89,
#  503,
#  90,
#  40,
#  22,
#  29,
#  64,
#  89,
#  10,
#  168,
#  175,
#  145,
#  0,
#  15,
#  0,
#  1,
#  95,
#  80,
#  10,
#  575,
#  38,
#  139,
#  60,
#  90,
#  40,
#  0,
#  59,
#  10,
#  500,
#  40,
#  25,
#  350,
#  7,
#  11,
#  71,
#  0,
#  5,
#  35,
#  50,
#  15,
#  200,
#  0,
#  29,
#  50,
#  1045,
#  20,
#  47,
#  65,
#  75,
#  23,
#  1950,
#  30,
#  5,
#  149,
#  23,
#  17,
#  21,
#  85,
#  79,
#  449,
#  149,
#  19,
#  40,
#  10,
#  675,
#  16,
#  2345,
#  0,
#  49,
#  75,
#  19,
#  139,
#  18,
#  9,
#  70,
#  20,
#  45,
#  25,
#  5,
#  89,
#  90,
#  33,
#  640,
#  25,
#  21,
#  60,
#  165,
#  194,
#  5,
#  59,
#  1,
#  -1,
#  -1,
#  -1,
#  191,
#  -1,
#  5,
#  325,
#  177,
#  1950,
#  125,
#  10,
#  250,
#  80,
#  95,
#  193,
#  15,
#  85,
#  6,
#  89,
#  350,
#  -1,
#  550,
#  40,
#  314,
#  10,
#  170,
#  135,
#  349,
#  50,
#  85,
#  400,
#  20,
#  1100,
#  425,
#  25,
#  20,
#  358,
#  26,
#  185,
#  1313,
#  325,
#  199,
#  13,
#  25,
#  49,
#  75,
#  14,
#  50,
#  21,
#  79,
#  323,
#  67,
#  447,
#  200,
#  9,
#  310,
#  29,
#  112,
#  75,
#  15,
#  105,
#  5,
#  84,
#  130,
#  1950,
#  39,
#  808,
#  195,
#  280,
#  20,
#  10,
#  26,
#  175,
#  26,
#  2650,
#  9,
#  85,
#  400,
#  200,
#  250,
#  32,
#  5,
#  20,
#  5,
#  119,
#  225,
#  149,
#  39,
#  4,
#  75,
#  28,
#  400,
#  29,
#  9,
#  28,
#  13,
#  75,
#  24,
#  4,
#  110,
#  945,
#  450,
#  1649,
#  23,
#  59,
#  235,
#  525,
#  300,
#  20,
#  200,
#  5,
#  9,
#  102,
#  1150,
#  270,
#  39,
#  22,
#  280,
#  9,
#  70,
#  39,
#  165,
#  11,
#  79,
#  8,
#  100,
#  0,
#  28,
#  160,
#  139,
#  130,
#  782,
#  245,
#  50,
#  200,
#  100,
#  349,
#  89,
#  350,
#  130,
#  85,
#  309,
#  14,
#  1,
#  5,
#  10,
#  23,
#  15,
#  5,
#  125,
#  89,
#  8,
#  15,
#  49,
#  10,
#  35,
#  145,
#  15,
#  1,
#  250,
#  20,
#  1550,
#  49,
#  549,
#  419,
#  150,
#  20,
#  229,
#  1450,
#  20,
#  350,
#  40,
#  0,
#  5,
#  179,
#  0,
#  425,
#  49,
#  100,
#  0,
#  10,
#  18,
#  170,
#  449,
#  5,
#  109,
#  0,
#  10,
#  200,
#  20,
#  28,
#  299,
#  110,
#  35,
#  7,
#  0,
#  210,
#  105,
#  200,
#  300,
#  2,
#  49,
#  7,
#  250,
#  19,
#  110,
#  750,
#  200,
#  350,
#  170,
#  45,
#  325,
#  0,
#  200,
#  50,
#  199,
#  325,
#  14,
#  100,
#  100,
#  90,
#  36,
#  97,
#  39,
#  13,
#  9,
#  130,
#  30,
#  299,
#  350,
#  150,
#  190,
#  42,
#  10,
#  25,
#  125,
#  5,
#  89,
#  1,
#  300,
#  93,
#  350,
#  350,
#  145,
#  199,
#  20,
#  10,
#  450,
#  180,
#  42,
#  49,
#  70,
#  50,
#  20,
#  549,
#  20,
#  19,
#  125,
#  65,
#  1,
#  37,
#  40,
#  50,
#  85,
#  250,
#  40,
#  15,
#  12,
#  100,
#  298,
#  80,
#  8,
#  5,
#  14,
#  10,
#  10,
#  15,
#  300,
#  225,
#  225,
#  10,
#  31,
#  5,
#  1200,
#  213,
#  5,
#  15,
#  11,
#  15,
#  550,
#  23,
#  2,
#  60,
#  10,
#  5,
#  16,
#  85,
#  4,
#  400,
#  30,
#  600,
#  440,
#  25,
#  20,
#  400,
#  90,
#  22,
#  250,
#  22,
#  6,
#  50,
#  70,
#  550,
#  5450,
#  250,
#  82,
#  193,
#  27,
#  68,
#  20,
#  210,
#  10,
#  275,
#  150,
#  70,
#  39,
#  85,
#  5,
#  10,
#  29,
#  1445,
#  350,
#  20,
#  600,
#  9,
#  62,
#  19,
#  105,
#  3654,
#  239,
#  1,
#  69,
#  32,
#  199,
#  90,
#  20,
#  450,
#  0,
#  39,
#  98,
#  12,
#  0,
#  70,
#  10,
#  10,
#  180,
#  75,
#  50,
#  300,
#  10,
#  235,
#  5,
#  175,
#  42,
#  35,
#  60,
#  175,
#  261,
#  5,
#  17,
#  16,
#  10,
#  9,
#  35,
#  288,
#  950,
#  50,
#  48,
#  190,
#  5,
#  75,
#  15,
#  75,
#  10,
#  59,
#  73,
#  85,
#  50,
#  21,
#  19,
#  10,
#  230,
#  145,
#  30,
#  36,
#  4,
#  30,
#  125,
#  5,
#  9,
#  225,
#  45,
#  0,
#  10,
#  4,
#  45,
#  300,
#  108,
#  19,
#  1249,
#  119,
#  349,
#  400,
#  2224,
#  50,
#  21,
#  125,
#  83,
#  249,
#  215,
#  29,
#  59,
#  49,
#  36,
#  12,
#  15,
#  10,
#  130,
#  3,
#  30,
#  60,
#  325,
#  5,
#  25,
#  69,
#  90,
#  0,
#  100,
#  49,
#  193,
#  5,
#  84,
#  55,
#  42,
#  10,
#  40,
#  10,
#  1150,
#  76,
#  100,
#  5,
#  25,
#  75,
#  200,
#  45,
#  169,
#  0,
#  149,
#  3,
#  125,
#  95,
#  40,
#  28,
#  0,
#  550,
#  200,
#  45,
#  350,
#  10,
#  10,
#  48,
#  0,
#  16,
#  87,
#  10,
#  69,
#  25,
#  16,
#  750,
#  4,
#  10,
#  1450,
#  280,
#  100,
#  15,
#  20,
#  950,
#  17,
#  159,
#  94,
#  12,
#  500,
#  268,
#  50,
#  800,
#  25,
#  39,
#  145,
#  475,
#  49,
#  10,
#  270,
#  5,
#  1,
#  45,
#  95,
#  6,
#  0,
#  100,
#  341,
#  0,
#  100,
#  146,
#  5,
#  5,
#  5,
#  40,
#  25,
#  48,
#  195,
#  0,
#  22,
#  8,
#  40,
#  -1,
#  -1,
#  19,
#  29,
#  60,
#  10,
#  325,
#  22,
#  8,
#  49,
#  22,
#  200,
#  200,
#  125,
#  5,
#  399,
#  75,
#  117,
#  84,
#  65,
#  10,
#  5,
#  75,
#  79,
#  20,
#  3,
#  13,
#  189,
#  198,
#  0,
#  745,
#  10,
#  0,
#  550,
#  29,
#  309,
#  200,
#  150,
#  135,
#  55,
#  4,
#  100,
#  25,
#  27,
#  85,
#  79,
#  115,
#  65,
#  185,
#  18,
#  10,
#  11,
#  39,
#  8,
#  1950,
#  50,
#  50,
#  15,
#  149,
#  5,
#  25,
#  225,
#  25,
#  834,
#  1949,
#  6,
#  40,
#  50,
#  71,
#  125,
#  14,
#  75,
#  18,
#  145,
#  64,
#  200,
#  65,
#  308,
#  49,
#  145,
#  35,
#  -1,
#  525,
#  49,
#  110,
#  20,
#  9,
#  22,
#  5,
#  30,
#  45,
#  25,
#  250,
#  15,
#  9,
#  275,
#  49,
#  108,
#  245,
#  80,
#  42,
#  5,
#  15,
#  50,
#  20,
#  81,
#  550,
#  3,
#  475,
#  50,
#  80,
#  195,
#  48,
#  341,
#  23,
#  450,
#  299,
#  13,
#  125,
#  14,
#  24,
#  18,
#  65,
#  850,
#  15,
#  245,
#  25,
#  140,
#  25,
#  275,
#  20,
#  10,
#  17,
#  90,
#  ...]

# %%
#taking the range (min and max) from the distances
minimum = price_dist[0]
for i in price_dist:
        if i < minimum and not(i == -1):
            minimum = i
rang = max(price_dist) - minimum

# %%
#finding the ratings
#logarith cause the range min-max is really high
rankings_price = {}
for i in range(len(price_dist)):
    if(price_dist[i] >= 0):
        #rankings_price[i] = 1 - ((price_dist[i] - minimum ) / rang)
        rankings_price[i] = 1-(numpy.log(price_dist[i]+1))/10
    else:
        rankings_price[i] = None
rankings_price
# Out:
# {0: 0.6821946169652054,
#  1: 0.5394829814011908,
#  2: 0.7697414907005954,
#  3: 0.760210472720163,
#  4: 0.6741903461978518,
#  5: 0.46966950919409245,
#  6: 0.5617973365326119,
#  7: 0.6741903461978518,
#  8: 0.430964054567594,
#  9: 0.686450578407085,
#  10: 0.7227411277760218,
#  11: 0.5795307380609034,
#  12: 0.5290469798687666,
#  13: 0.5889126135826689,
#  14: 0.5163718093048522,
#  15: 0.6336438353870354,
#  16: 0.650349243853352,
#  17: 0.4579465000727714,
#  18: 0.2719991747115812,
#  19: 0.46966950919409245,
#  20: 0.20104395506661343,
#  21: 0.4292889735251124,
#  22: 0.5246409808893635,
#  23: 0.7227411277760218,
#  24: 0.6068174367275674,
#  25: None,
#  26: 0.729194979889779,
#  27: 0.7227411277760218,
#  28: 0.5889126135826689,
#  29: 0.3601405065464792,
#  30: 0.5023266257579426,
#  31: 0.6741903461978518,
#  32: 0.6534264097200273,
#  33: 0.5751504757950641,
#  34: 0.4829516004961849,
#  35: 0.6336438353870354,
#  36: 0.641648106154389,
#  37: 0.5974648309264851,
#  38: 0.38907524172356345,
#  39: 0.6741903461978518,
#  40: 0.7227411277760218,
#  41: 0.42285588768699844,
#  42: 0.38885326604973214,
#  43: 0.7227411277760218,
#  44: 0.641648106154389,
#  45: 1.0,
#  46: 0.5780492294823893,
#  47: 0.4727000441436253,
#  48: 0.33141390529316406,
#  49: 0.8901387711331891,
#  50: 0.4006038572693431,
#  51: 0.4474547060868217,
#  52: 0.49374049669730335,
#  53: 0.6068174367275674,
#  54: 0.5974648309264851,
#  55: 0.6534264097200273,
#  56: 0.760210472720163,
#  57: 0.5737320122958685,
#  58: 0.7697414907005954,
#  59: 0.8208240530771945,
#  60: 0.6955477562276577,
#  61: 0.4989364705903745,
#  62: 0.7435050642538463,
#  63: 0.46966950919409245,
#  64: 0.8208240530771945,
#  65: 0.3378594348235866,
#  66: 0.760210472720163,
#  67: 0.538487948315874,
#  68: 0.30588099449316253,
#  69: 0.7227411277760218,
#  70: 0.560555084532756,
#  71: 0.6632704170013526,
#  72: 0.5889126135826689,
#  73: 0.700426772644601,
#  74: 0.5810345257973575,
#  75: 0.6741903461978518,
#  76: 1.0,
#  77: 0.5669266659713669,
#  78: 0.4474547060868217,
#  79: 0.3378594348235866,
#  80: 0.3378594348235866,
#  81: 0.6741903461978518,
#  82: 1.0,
#  83: 0.7227411277760218,
#  84: 0.5545652703746493,
#  85: 0.7227411277760218,
#  509: 0.4561920691076804,
#  510: 0.2719991747115812,
#  511: 0.6955477562276577,
#  512: 0.4139213776534134,
#  513: 0.6286427933295692,
#  514: 1.0,
#  515: 0.8208240530771945,
#  516: 0.480704314910979,
#  517: 1.0,
#  518: 0.39455606537306287,
#  519: 0.6087976994571854,
#  520: 0.538487948315874,
#  521: 1.0,
#  522: 0.760210472720163,
#  523: 0.705556102083356,
#  524: 0.485833644349734,
#  525: 0.38907524172356345,
#  526: 0.8208240530771945,
#  527: 0.5299519634207583,
#  528: 1.0,
#  529: 0.760210472720163,
#  530: 0.46966950919409245,
#  531: 0.6955477562276577,
#  532: 0.6632704170013526,
#  533: 0.42962175253437995,
#  534: 0.5290469798687666,
#  535: 0.641648106154389,
#  536: 0.7920558458320164,
#  537: 1.0,
#  538: 0.4648141866523934,
#  539: 0.5336560905887933,
#  540: 0.46966950919409245,
#  541: 0.4292889735251124,
#  542: 0.8901387711331891,
#  543: 0.6087976994571854,
#  544: 0.7920558458320164,
#  545: 0.4474547060868217,
#  546: 0.700426772644601,
#  547: 0.5290469798687666,
#  548: 0.3378594348235866,
#  549: 0.46966950919409245,
#  550: 0.4139213776534134,
#  551: 0.485833644349734,
#  552: 0.6171358603510905,
#  553: 0.4213102618633292,
#  554: 1.0,
#  555: 0.46966950919409245,
#  556: 0.6068174367275674,
#  557: 0.47016826334519635,
#  558: 0.4213102618633292,
#  559: 0.729194979889779,
#  560: 0.538487948315874,
#  561: 0.538487948315874,
#  562: 0.548914049348315,
#  563: 0.6389082087355775,
#  564: 0.5415032521329428,
#  565: 0.6311120545886064,
#  566: 0.7360942670384741,
#  567: 0.7697414907005954,
#  568: 0.5124802676798849,
#  569: 0.6566012795514854,
#  570: 0.42962175253437995,
#  571: 0.4139213776534134,
#  572: 0.4982720163185076,
#  573: 0.474772657195337,
#  574: 0.6238799884306437,
#  575: 0.760210472720163,
#  576: 0.6741903461978518,
#  577: 0.5163718093048522,
#  578: 0.8208240530771945,
#  579: 0.5500190329669735,
#  580: 0.9306852819440055,
#  581: 0.4292889735251124,
#  582: 0.5456705217729996,
#  583: 0.4139213776534134,
#  584: 0.4139213776534134,
#  585: 0.5016393378291664,
#  586: 0.47016826334519635,
#  587: 0.6955477562276577,
#  588: 0.760210472720163,
#  589: 0.38885326604973214,
#  590: 0.48015029687341737,
#  591: 0.6238799884306437,
#  592: 0.6087976994571854,
#  593: 0.5737320122958685,
#  594: 0.6068174367275674,
#  595: 0.6955477562276577,
#  596: 0.3690081721773484,
#  597: 0.6955477562276577,
#  598: 0.700426772644601,
#  599: 0.5163718093048522,
#  600: 0.5810345257973575,
#  601: 0.9306852819440055,
#  602: 0.6362413840273614,
#  603: 0.6286427933295692,
#  604: 0.6068174367275674,
#  605: 0.5545652703746493,
#  606: 0.4474547060868217,
#  607: 0.6286427933295692,
#  608: 0.7227411277760218,
#  609: 0.7435050642538463,
#  610: 0.538487948315874,
#  611: 0.42995564266093134,
#  612: 0.560555084532756,
#  613: 0.780277542266378,
#  614: 0.8208240530771945,
#  929: 0.3272568275149145,
#  930: 0.2424415348442207,
#  931: 0.8054089850944687,
#  932: 0.6286427933295692,
#  933: 0.6068174367275674,
#  934: 0.5723333880983945,
#  935: 0.5163718093048522,
#  936: 0.729194979889779,
#  937: 0.5669266659713669,
#  938: 0.705556102083356,
#  939: 0.5016393378291664,
#  940: 0.5825612730104364,
#  941: 0.46966950919409245,
#  942: 0.5810345257973575,
#  943: 0.42666587231022546,
#  944: 0.6087976994571854,
#  945: 0.5016393378291664,
#  946: 0.641648106154389,
#  947: None,
#  948: 0.37346987872622894,
#  949: 0.6087976994571854,
#  950: 0.5290469798687666,
#  951: 0.6955477562276577,
#  952: 0.7697414907005954,
#  953: 0.686450578407085,
#  954: 0.8208240530771945,
#  955: 0.6566012795514854,
#  956: 0.6171358603510905,
#  957: 0.6741903461978518,
#  958: 0.4474547060868217,
#  959: 0.7227411277760218,
#  960: 0.7697414907005954,
#  961: 0.437959913428285,
#  962: 0.6087976994571854,
#  963: 0.5308652117770857,
#  964: 0.4494668464067637,
#  965: 0.560555084532756,
#  966: 0.6238799884306437,
#  967: 0.8208240530771945,
#  968: 0.7227411277760218,
#  969: 0.6068174367275674,
#  970: 0.6955477562276577,
#  971: 0.5593280752735746,
#  972: 0.36882651908470854,
#  973: 0.8613705638880109,
#  974: 0.3834582145768579,
#  975: 0.6068174367275674,
#  976: 0.560555084532756,
#  977: 0.4721885340769483,
#  978: 0.6108179701889374,
#  979: 0.41651892629373954,
#  980: 0.6821946169652054,
#  981: 0.38885326604973214,
#  982: 0.42962175253437995,
#  983: 0.7360942670384741,
#  984: 0.5163718093048522,
#  985: 0.729194979889779,
#  986: 0.67811241751318,
#  987: 0.705556102083356,
#  988: 0.5810345257973575,
#  989: 0.32535878714266253,
#  990: 0.7227411277760218,
#  991: 0.4494668464067637,
#  992: 0.6741903461978518,
#  993: 0.5051240109621832,
#  994: 0.6741903461978518,
#  995: 0.437959913428285,
#  996: 0.6955477562276577,
#  997: 0.760210472720163,
#  998: 0.7109628242103836,
#  999: 0.548914049348315,
#  ...}

# %%
price_dist
# Out:
# [23,
#  99,
#  9,
#  10,
#  25,
#  200,
#  79,
#  25,
#  295,
#  22,
#  15,
#  66,
#  110,
#  60,
#  125,
#  38,
#  32,
#  225,
#  1450,
#  200,
#  2949,
#  300,
#  115,
#  15,
#  50,
#  -1,
#  14,
#  15,
#  60,
#  600,
#  144,
#  25,
#  31,
#  69,
#  175,
#  38,
#  35,
#  55,
#  449,
#  25,
#  15,
#  320,
#  450,
#  15,
#  35,
#  0,
#  67,
#  194,
#  800,
#  2,
#  400,
#  250,
#  157,
#  50,
#  55,
#  31,
#  10,
#  70,
#  9,
#  5,
#  20,
#  149,
#  12,
#  200,
#  5,
#  750,
#  10,
#  100,
#  1033,
#  15,
#  80,
#  28,
#  60,
#  19,
#  65,
#  25,
#  0,
#  75,
#  250,
#  750,
#  750,
#  25,
#  0,
#  15,
#  85,
#  15,
#  5,
#  225,
#  39,
#  150,
#  700,
#  150,
#  2,
#  95,
#  30,
#  10,
#  950,
#  295,
#  600,
#  25,
#  49,
#  50,
#  325,
#  -1,
#  -1,
#  -1,
#  145,
#  295,
#  13,
#  59,
#  10,
#  149,
#  20,
#  5,
#  20,
#  14,
#  139,
#  450,
#  300,
#  150,
#  30,
#  350,
#  115,
#  100,
#  5,
#  0,
#  10,
#  45,
#  285,
#  65,
#  5,
#  11,
#  60,
#  48,
#  125,
#  30,
#  11,
#  25,
#  75,
#  300,
#  24,
#  100,
#  42,
#  91,
#  150,
#  53,
#  9,
#  55,
#  10,
#  140,
#  150,
#  200,
#  10,
#  65,
#  239,
#  718,
#  0,
#  200,
#  205,
#  65,
#  11,
#  450,
#  404,
#  722,
#  100,
#  151,
#  50,
#  -1,
#  90,
#  -1,
#  -1,
#  -1,
#  -1,
#  20,
#  89,
#  10,
#  653,
#  -1,
#  150,
#  -1,
#  -1,
#  -1,
#  30,
#  550,
#  24,
#  8,
#  58,
#  119,
#  40,
#  24,
#  65,
#  275,
#  49,
#  225,
#  412,
#  85,
#  375,
#  27,
#  50,
#  69,
#  24,
#  30,
#  193,
#  139,
#  91,
#  13,
#  79,
#  245,
#  20,
#  159,
#  36,
#  73,
#  5,
#  79,
#  5,
#  275,
#  30,
#  12,
#  360,
#  51,
#  5,
#  8,
#  45,
#  301,
#  300,
#  22,
#  110,
#  5,
#  86,
#  5,
#  200,
#  110,
#  137,
#  49,
#  950,
#  110,
#  125,
#  583,
#  550,
#  200,
#  5,
#  135,
#  215,
#  155,
#  50,
#  143,
#  3,
#  9,
#  200,
#  100,
#  20,
#  89,
#  503,
#  90,
#  40,
#  22,
#  29,
#  64,
#  89,
#  10,
#  168,
#  175,
#  145,
#  0,
#  15,
#  0,
#  1,
#  95,
#  80,
#  10,
#  575,
#  38,
#  139,
#  60,
#  90,
#  40,
#  0,
#  59,
#  10,
#  500,
#  40,
#  25,
#  350,
#  7,
#  11,
#  71,
#  0,
#  5,
#  35,
#  50,
#  15,
#  200,
#  0,
#  29,
#  50,
#  1045,
#  20,
#  47,
#  65,
#  75,
#  23,
#  1950,
#  30,
#  5,
#  149,
#  23,
#  17,
#  21,
#  85,
#  79,
#  449,
#  149,
#  19,
#  40,
#  10,
#  675,
#  16,
#  2345,
#  0,
#  49,
#  75,
#  19,
#  139,
#  18,
#  9,
#  70,
#  20,
#  45,
#  25,
#  5,
#  89,
#  90,
#  33,
#  640,
#  25,
#  21,
#  60,
#  165,
#  194,
#  5,
#  59,
#  1,
#  -1,
#  -1,
#  -1,
#  191,
#  -1,
#  5,
#  325,
#  177,
#  1950,
#  125,
#  10,
#  250,
#  80,
#  95,
#  193,
#  15,
#  85,
#  6,
#  89,
#  350,
#  -1,
#  550,
#  40,
#  314,
#  10,
#  170,
#  135,
#  349,
#  50,
#  85,
#  400,
#  20,
#  1100,
#  425,
#  25,
#  20,
#  358,
#  26,
#  185,
#  1313,
#  325,
#  199,
#  13,
#  25,
#  49,
#  75,
#  14,
#  50,
#  21,
#  79,
#  323,
#  67,
#  447,
#  200,
#  9,
#  310,
#  29,
#  112,
#  75,
#  15,
#  105,
#  5,
#  84,
#  130,
#  1950,
#  39,
#  808,
#  195,
#  280,
#  20,
#  10,
#  26,
#  175,
#  26,
#  2650,
#  9,
#  85,
#  400,
#  200,
#  250,
#  32,
#  5,
#  20,
#  5,
#  119,
#  225,
#  149,
#  39,
#  4,
#  75,
#  28,
#  400,
#  29,
#  9,
#  28,
#  13,
#  75,
#  24,
#  4,
#  110,
#  945,
#  450,
#  1649,
#  23,
#  59,
#  235,
#  525,
#  300,
#  20,
#  200,
#  5,
#  9,
#  102,
#  1150,
#  270,
#  39,
#  22,
#  280,
#  9,
#  70,
#  39,
#  165,
#  11,
#  79,
#  8,
#  100,
#  0,
#  28,
#  160,
#  139,
#  130,
#  782,
#  245,
#  50,
#  200,
#  100,
#  349,
#  89,
#  350,
#  130,
#  85,
#  309,
#  14,
#  1,
#  5,
#  10,
#  23,
#  15,
#  5,
#  125,
#  89,
#  8,
#  15,
#  49,
#  10,
#  35,
#  145,
#  15,
#  1,
#  250,
#  20,
#  1550,
#  49,
#  549,
#  419,
#  150,
#  20,
#  229,
#  1450,
#  20,
#  350,
#  40,
#  0,
#  5,
#  179,
#  0,
#  425,
#  49,
#  100,
#  0,
#  10,
#  18,
#  170,
#  449,
#  5,
#  109,
#  0,
#  10,
#  200,
#  20,
#  28,
#  299,
#  110,
#  35,
#  7,
#  0,
#  210,
#  105,
#  200,
#  300,
#  2,
#  49,
#  7,
#  250,
#  19,
#  110,
#  750,
#  200,
#  350,
#  170,
#  45,
#  325,
#  0,
#  200,
#  50,
#  199,
#  325,
#  14,
#  100,
#  100,
#  90,
#  36,
#  97,
#  39,
#  13,
#  9,
#  130,
#  30,
#  299,
#  350,
#  150,
#  190,
#  42,
#  10,
#  25,
#  125,
#  5,
#  89,
#  1,
#  300,
#  93,
#  350,
#  350,
#  145,
#  199,
#  20,
#  10,
#  450,
#  180,
#  42,
#  49,
#  70,
#  50,
#  20,
#  549,
#  20,
#  19,
#  125,
#  65,
#  1,
#  37,
#  40,
#  50,
#  85,
#  250,
#  40,
#  15,
#  12,
#  100,
#  298,
#  80,
#  8,
#  5,
#  14,
#  10,
#  10,
#  15,
#  300,
#  225,
#  225,
#  10,
#  31,
#  5,
#  1200,
#  213,
#  5,
#  15,
#  11,
#  15,
#  550,
#  23,
#  2,
#  60,
#  10,
#  5,
#  16,
#  85,
#  4,
#  400,
#  30,
#  600,
#  440,
#  25,
#  20,
#  400,
#  90,
#  22,
#  250,
#  22,
#  6,
#  50,
#  70,
#  550,
#  5450,
#  250,
#  82,
#  193,
#  27,
#  68,
#  20,
#  210,
#  10,
#  275,
#  150,
#  70,
#  39,
#  85,
#  5,
#  10,
#  29,
#  1445,
#  350,
#  20,
#  600,
#  9,
#  62,
#  19,
#  105,
#  3654,
#  239,
#  1,
#  69,
#  32,
#  199,
#  90,
#  20,
#  450,
#  0,
#  39,
#  98,
#  12,
#  0,
#  70,
#  10,
#  10,
#  180,
#  75,
#  50,
#  300,
#  10,
#  235,
#  5,
#  175,
#  42,
#  35,
#  60,
#  175,
#  261,
#  5,
#  17,
#  16,
#  10,
#  9,
#  35,
#  288,
#  950,
#  50,
#  48,
#  190,
#  5,
#  75,
#  15,
#  75,
#  10,
#  59,
#  73,
#  85,
#  50,
#  21,
#  19,
#  10,
#  230,
#  145,
#  30,
#  36,
#  4,
#  30,
#  125,
#  5,
#  9,
#  225,
#  45,
#  0,
#  10,
#  4,
#  45,
#  300,
#  108,
#  19,
#  1249,
#  119,
#  349,
#  400,
#  2224,
#  50,
#  21,
#  125,
#  83,
#  249,
#  215,
#  29,
#  59,
#  49,
#  36,
#  12,
#  15,
#  10,
#  130,
#  3,
#  30,
#  60,
#  325,
#  5,
#  25,
#  69,
#  90,
#  0,
#  100,
#  49,
#  193,
#  5,
#  84,
#  55,
#  42,
#  10,
#  40,
#  10,
#  1150,
#  76,
#  100,
#  5,
#  25,
#  75,
#  200,
#  45,
#  169,
#  0,
#  149,
#  3,
#  125,
#  95,
#  40,
#  28,
#  0,
#  550,
#  200,
#  45,
#  350,
#  10,
#  10,
#  48,
#  0,
#  16,
#  87,
#  10,
#  69,
#  25,
#  16,
#  750,
#  4,
#  10,
#  1450,
#  280,
#  100,
#  15,
#  20,
#  950,
#  17,
#  159,
#  94,
#  12,
#  500,
#  268,
#  50,
#  800,
#  25,
#  39,
#  145,
#  475,
#  49,
#  10,
#  270,
#  5,
#  1,
#  45,
#  95,
#  6,
#  0,
#  100,
#  341,
#  0,
#  100,
#  146,
#  5,
#  5,
#  5,
#  40,
#  25,
#  48,
#  195,
#  0,
#  22,
#  8,
#  40,
#  -1,
#  -1,
#  19,
#  29,
#  60,
#  10,
#  325,
#  22,
#  8,
#  49,
#  22,
#  200,
#  200,
#  125,
#  5,
#  399,
#  75,
#  117,
#  84,
#  65,
#  10,
#  5,
#  75,
#  79,
#  20,
#  3,
#  13,
#  189,
#  198,
#  0,
#  745,
#  10,
#  0,
#  550,
#  29,
#  309,
#  200,
#  150,
#  135,
#  55,
#  4,
#  100,
#  25,
#  27,
#  85,
#  79,
#  115,
#  65,
#  185,
#  18,
#  10,
#  11,
#  39,
#  8,
#  1950,
#  50,
#  50,
#  15,
#  149,
#  5,
#  25,
#  225,
#  25,
#  834,
#  1949,
#  6,
#  40,
#  50,
#  71,
#  125,
#  14,
#  75,
#  18,
#  145,
#  64,
#  200,
#  65,
#  308,
#  49,
#  145,
#  35,
#  -1,
#  525,
#  49,
#  110,
#  20,
#  9,
#  22,
#  5,
#  30,
#  45,
#  25,
#  250,
#  15,
#  9,
#  275,
#  49,
#  108,
#  245,
#  80,
#  42,
#  5,
#  15,
#  50,
#  20,
#  81,
#  550,
#  3,
#  475,
#  50,
#  80,
#  195,
#  48,
#  341,
#  23,
#  450,
#  299,
#  13,
#  125,
#  14,
#  24,
#  18,
#  65,
#  850,
#  15,
#  245,
#  25,
#  140,
#  25,
#  275,
#  20,
#  10,
#  17,
#  90,
#  ...]
