# %% [markdown]
# # Homework 3 - Find the perfect place to stay in Texas!
#
# ###### Alessandro Flaborea, Egon Ferri, Melis Kaymaz

# %% [markdown]
# The homework consists in analyzing the text of Airbnb property listings and building a search engine.

# %%
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize, PunktSentenceTokenizer
from nltk.corpus import stopwords
#nltk.download()
import string
from nltk.stem import PorterStemmer
from nltk import pos_tag, ne_chunk
import nltk
import math

# %% [markdown]
# ## Step 2: Create documents

# %% [markdown]
# We want to create a `.tsv` file for each record of the dataset.
# First thing to do is reading the file.

# %%
f = pd.read_csv(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\Airbnb_Texas_Rentals.csv')

# %% [markdown]
# Now we can create `.tsv` files and store them in a directory.

# %%
for i in range(f.index.max()+1):
    op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\doc\doc_' + str(i) + '.tsv', 'w', encoding="utf-8")
    for j in range(10):
        op.write('%s\t' %f.iloc[i, j])
    op.close()

# %% [markdown]
# ## Step 3: Search Engine

# %% [markdown]
# Now, we want to create two different Search Engines that, given as input a query, return the houses that match the query.
#
# As a first common step, we want to preprocess the documents by
#
# 1. Removing stopwords
# 2. Removing punctuation
# 3. Stemming
#
# Then we want to build a file named `vocabulary.txt`, that maps each word to an integer (`term_id`).

# %%
#FUNCTIONS
def preprocess(l):
    final = []
    for i in l:
        if not((ps.stem(i) in stopWords) or (ps.stem(i) in (string.punctuation) )):
            final.append(ps.stem(i))
    return (final)

def vocabularization(vocabulary, final, index):
    for word in final:
        if not(word in vocabulary):
            vocabulary[word] = index
            index = index + 1
    return(vocabulary, index)

#not used at the moment
def chunking(sentence):
    names = []
    l = []
    for chunk in ne_chunk(pos_tag(word_tokenize(sentence))) : 
        if type(chunk) is nltk.tree.Tree:
            s = ''
            for  i in chunk:
                s = s + ' ' + i[0]
            names.append(s[1:])
        else:
            l.append(chunk[0])
    return(names, l)

# %%
stopWords = set(stopwords.words('english'))
ps = PorterStemmer()
string.punctuation = string.punctuation + '–“”’'

vocabulary= {}
index = 0

for i in range(18259):
    
    op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\doc\doc_' + str(i) + '.tsv', 'r', encoding="utf-8")
    for line in op:
        ou = line.strip().split('\t')
        sentence = ou[5].replace('\\n', ' ').replace('/', ' ').replace('*', ' ').replace('\\r', ' ').replace('\\t', ' ') + ' ' + ou[8]
    op.close()
        
    #preprocessing data deleting stop words, punctuations, ecc.  
    final = preprocess(word_tokenize(sentence))
    
    # IF  word not in vocabulary -> add the word
    vocabulary, index = vocabularization(vocabulary, final, index)
            
op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\vocabulary.txt', 'w', encoding="utf-8")
op.write(str(vocabulary))
op.close()

# %% [markdown]
# ### 3.1) Conjunctive query
# At this moment, we narrow out interest on the `description` and `title` of each document. It means that the first Search Engine will evaluate queries with respect to the aforementioned information.

# %% [markdown]
# #### 3.1.1) Creating our index!
#
# We want to create the Inverted Index. It will be a dictionary of this format:
#
# ```
# {
# term_id_1:[document_1, document_2, document_4],
# term_id_2:[document_1, document_3, document_5, document_6],
# ...}
# ```
#
# where _document\_i_ is the *id* of a document that contains the word.
#
# We also want to store it in a separate file and load it in memory when needed.

# %%
inverted_index = {}

for file in range(18259):

    op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\doc\doc_' + str(file) + '.tsv', 'r', encoding="utf-8")
    for line in op:
        ou = line.strip().split('\t')
        sentence = ou[5].replace('\\n', ' ').replace('/', ' ').replace('*', ' ').replace('\\r', ' ').replace('\\t', ' ') + ' ' + ou[8]
    op.close()
 
    
    #preprocessing data deleting stop words, punctuations, ecc.  
    final = preprocess(word_tokenize(sentence))
    
    
    #CREATING INVERTED INDEX
    for word in final:
        index = vocabulary[word]
        if not (index in inverted_index):
            inverted_index[index] = ['doc_' + str(file)]
        elif not('doc_' + str(file) in inverted_index[index]):
            inverted_index[index] = inverted_index[index] + ['doc_' + str(file)]

op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\inverted_index.txt', 'w', encoding="utf-8")
op.write(str(inverted_index))
op.close()

# %% [markdown]
# #### 3.1.2) Execute the query
# Now given a query, that we let the user enter:
# ```
# queen netflix
# ```
# we want that the Search Engine returns a list of documents that contains all the words in the query.

# %% [markdown]
# Query input:

# %%
user_query = input()

#names, l = chunking(sentence) 
    
#preprocessing data deleting stop words, punctuations, ecc.  
final = preprocess(word_tokenize(user_query))
final
# Out:
# queen netflix
# ['queen', 'netflix']

# %% [markdown]
# Traducing the query in our 'language':

# %%
voc = {}
inverted_idx = {}
i=0
for word in final: 
    voc[i]  = vocabulary[word]
    i = i+1
for index in range(i):
    inverted_idx[voc[index]] = inverted_index[voc[index]]

# %% [markdown]
# Finding list of docs that contain all the words in the query and printing them in the format that we want:

# %%
finding list of docs that contain all the words in the query
docs = []

for i in range(18259):
    doc = 'doc_' + str(i)
    b = True
    for j in voc.values(): 
        b = b and (doc in inverted_idx[j])
    if b:
        docs.append(i)

df = f.filter(items = ['title', 'description', 'city', 'url']).loc[docs]
df.description = list(map(lambda x: x.replace('\\n', ' '), df.description.tolist()))
df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_ffb3db68_e842_11e8_8305_204747782cb8" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >title</th>
#         <th class="col_heading level0 col1" >description</th>
#         <th class="col_heading level0 col2" >city</th>
#         <th class="col_heading level0 col3" >url</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row0_col0" class="data row0 col0" >Next to Stadiums! Updated, Modern 1 BD apt</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row0_col1" class="data row0 col1" >Cozy and comfortable modern 1 BD apt. This apt is in the middle of EVERYTHING. Tons of restaurants and tourist attractions with in 1-2 miles. A second floor unit overlooking the pool. Comfortable king size Serta memory foam mattress in the bedroom, and a comfortable couch and love seat in the living room, along with a queen size air mattress. High speed internet and Netflix provided. This apartment is the perfect place if you are coming to town for the theme Parks or anything at ATT stadium.</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row0_col2" class="data row0 col2" >Arlington</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row0_col3" class="data row0 col3" >https://www.airbnb.com/rooms/18363018?location=Bedford%2C%20TX</td>
#     </tr>    <tr>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row1_col0" class="data row1 col0" >Great room on East Downtown</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row1_col1" class="data row1 col1" >Nice Bedroom, 2 beds (1 full, 1 twin, soon to be 1 queen in September 2017) with private bathroom, fridge, desk, and microwave...Also wifi, cable, Netflix, and Hulu. Only two blocks from Metro station and less that 10 min to downtown, Minute Maid and Dynamo Stadium!</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row1_col2" class="data row1 col2" >Houston</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row1_col3" class="data row1 col3" >https://www.airbnb.com/rooms/15254951?location=Baytown%2C%20TX</td>
#     </tr>    <tr>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row2_col0" class="data row2 col0" >1BR perfect location near UT, downtown, Cherrywood</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row2_col1" class="data row2 col1" >Location! - Walk to UT campus! - 10 minute drive downtown!  Apartment features - 50 inch HD 4k TV Netflix, surround sound, bluetooth - Fully stocked kitchen - Queen size bed with ultra plush mattress - microfiber sheets, antimicrobial silicone pillows - 2 towel sets + 2 additional pool towels  Building features - Secure covered parking - Resort-style pool, gas grills, covered lounge with big screen cable TVs - Game room with a pool table, cable TVs - 24 hour gym</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row2_col2" class="data row2 col2" >Austin</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row2_col3" class="data row2 col3" >https://www.airbnb.com/rooms/15604021?location=Austin%2C%20TX</td>
#     </tr>    <tr>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row3_col0" class="data row3 col0" >Glam Celebrity Home in UP! 4BR. 10% for Charity!</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row3_col1" class="data row3 col1" >Host your holiday get together here!!! Enjoy staying in our luxurious new 4 Bedroom, 4.5 Bath University Park 3700 sf home in the prestigious Park Cities! Previous Celebrity Home now can be yours! All bedrooms have attached bathrooms. 5 HD TV's. Netflix. HULU. HBO. Cable. WIFI. 8 beds (1K, 5 Queen, 2 Twin) + 4 inflatables. Whether a business traveler, bridal party, or family, come stay at a home and AirBnB of professional athletes, socialites, and other celebrities! Close to everything!</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row3_col2" class="data row3 col2" >Dallas</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row3_col3" class="data row3 col3" >https://www.airbnb.com/rooms/14668342?location=Arlington%2C%20TX</td>
#     </tr>    <tr>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row4_col0" class="data row4 col0" >Great room on East Downtown</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row4_col1" class="data row4 col1" >Nice Bedroom, 2 beds (1 full, 1 twin, soon to be 1 queen in September 2017) with private bathroom, fridge, desk, and microwave...Also wifi, cable, Netflix, and Hulu. Only two blocks from Metro station and less that 10 min to downtown, Minute Maid and Dynamo Stadium!</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row4_col2" class="data row4 col2" >Houston</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row4_col3" class="data row4 col3" >https://www.airbnb.com/rooms/15254951?location=Atascocita%2C%20TX</td>
#     </tr>    <tr>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row5_col0" class="data row5 col0" >Luxury Oceanview Condo</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row5_col1" class="data row5 col1" >This luxury ocean view condo is a short walk directly onto Whitecap beach on Padre Island! Enjoy beautiful views from your private balcony, LR and MBR. Very tastefully decorated unit has it all! Flat-screen cable TVs in LR and MBR, Netflix and Blueray DVD. High-speed internet in the unit allows you to work or play online at no additional cost. Feel at home for as long as you like with washer and dryer, and clean, modern full kitchen. The beautifully appointed MBR has pillow-top queen bed, walk-in closet and large bathroom with tub and shower. The LR has a queen sleeper sofa, balcony and fireplace. Amenities onsite include a beautiful pool and hot tub and a well equipped fitness center. Pond, inlet and surf-fishing are available on the property or within easy walk. Restaurants and nightlife abound on Padre Island and in nearby Port Aransas. Padre Island National Park and Mustang Island State Park are also close by; everything you could want for an unforgettable beach vacation!</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row5_col2" class="data row5 col2" >Corpus Christi</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row5_col3" class="data row5 col3" >https://www.airbnb.com/rooms/1022134?location=Baffin%20Bay%2C%20TX</td>
#     </tr>    <tr>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row6_col0" class="data row6 col0" >Just outside Austin ATX, Queen room</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row6_col1" class="data row6 col1" >You will have room with queen bed upstairs in my beautiful house, access to sitting areas, two bathrooms, living room w/ Netflix, cool backyard patio/fire pit, kitchen, dining room, laundry, etc.   Perfect for business or tourism travelers. Close to Dell, Samsung, Apple, etc. An easy drive to downtown Austin. Great for ACL, SXSW, and Formula 1. Close to the Domain, Georgetown, Round Rock (and RR Outlets), Pflugerville, Leander, Cedar Park, Austin, Manor, etc. ! You'll love it.</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row6_col2" class="data row6 col2" >Pflugerville</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row6_col3" class="data row6 col3" >https://www.airbnb.com/rooms/13548463?location=Coupland%2C%20TX</td>
#     </tr>    <tr>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row7_col0" class="data row7 col0" >Clean Bedroom and Bath Near Austin City Limit</td>
#         <td id="T_ffb3db68_e842_11e8_8305_204747782cb8row7_col1" class="data row7 col1" >Private bedroom upstairs in our new house. The room features a queen sized bed and a twin sized bed, TV with Netflix, a desk and a full bathroom. There is also a mini fridge, microwave and a water cooler in the room for your private use.  Our house is in the city of Manor, just outside of the Austin City Limits. We are a 15-20 minute drive to any part of Austin

# %% [markdown]
# ### 3.2) Conjunctive query & Ranking score
# In the new Search Engine, given a query, we want to get the *top-k* (the choice of *k* it's up to you!) documents related to the query. In particular we want:
#
# * Find all the documents that contains all the words in the query (as before...).
# * Sort them by their similarity with the query
# * Return in output *k* documents, or all the documents with non-zero similarity with the query when the results are less than _k_.
#
# To solve this task, we use the *tfIdf* score, and the _Cosine similarity_. Let's see how.

# %% [markdown]
# First thing; we create a new inverted index that contains `tfIdf`s:

# %%
inverted_index_2 = {}

for file in range(18259):

    op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\doc\doc_' + str(file) + '.tsv', 'r', encoding="utf-8")
    for line in op:
        ou = line.strip().split('\t')
        sentence = ou[5].replace('\\n', ' ').replace('/', ' ').replace('*', ' ').replace('\\r', ' ').replace('\\t', ' ') + ' ' + ou[8]
    op.close()
 
    
    #preprocessing data deleting stop words, punctuations, ecc.  
    final = preprocess(word_tokenize(sentence))
    
    
    #CREATING INVERTED INDEX
    for word in final:
        index = vocabulary[word]
        
        tf = final.count(word) / len(final)
        idf = math.log( 18258 / len(inverted_index[vocabulary[word]]))
        
        if not (index in inverted_index_2):
            inverted_index_2[index] = [('doc_' + str(file), tf*idf )]
        elif not(('doc_' + str(file), tf*idf)  in inverted_index_2[index]):
            inverted_index_2[index] = inverted_index_2[index] + [('doc_' + str(file), tf*idf)]


op = open(r'C:\Users\mccol\Desktop\Sapienza\ADM\HW3\inverted_index_2.txt', 'w', encoding="utf-8")
op.write(str(inverted_index_2))
op.close()

# %% [markdown]
# Query input:

# %%
user_query = input()

#preprocessing data deleting stop words, punctuations, ecc.  
final_query = preprocess(word_tokenize(user_query))
final_query
# Out:
# rare lake netflix
# ['rare', 'lake', 'netflix']

# %% [markdown]
# Traducing the query in our 'language':

# %%
voc = {}
inverted_query = {}
i=0
for word in final_query: 
    voc[i]  = vocabulary[word]
    i = i+1
for index in range(i):
    inverted_query[voc[index]] = inverted_index_2[voc[index]]

# %% [markdown]
# finding nominator of cosine similarity formula:

# %%
n = {}
index = 0
for i in inverted_query:
    for j in inverted_query[i]:
        if index == 0:
            n[j[0]] = [j[1]]
        elif (not (j[0] in n)):
            n[j[0]] = [0]*index + ([j[1]])
        else:   
            n[j[0]] = n[j[0]] + [0]*(index - len(n[j[0]])) + ([j[1]])
    index = index + 1

for i in n:
    if len(n[i]) < len(final_query) :
        n[i] = n[i] + [0]*(len(final_query)-len(n[i]))
n
# Out:
# {'doc_1340': [0.2327329197543106, 0, 0],
#  'doc_1344': [0.1253177260215519, 0, 0],
#  'doc_2831': [0.10343685322413805, 0, 0],
#  'doc_4026': [0.09873517807758633, 0, 0],
#  'doc_4659': [0.19747035615517267, 0.1318841827724638, 0],
#  'doc_6071': [0.1253177260215519, 0, 0],
#  'doc_6186': [0.01916624045035499, 0, 0],
#  'doc_6191': [0.17148741455580782, 0, 0],
#  'doc_7522': [0.15893955495416334, 0, 0],
#  'doc_8201': [0.08926742127562598, 0, 0],
#  'doc_8628': [0.11235382332966719, 0, 0],
#  'doc_9516': [0.10343685322413805, 0, 0],
#  'doc_9707': [0.05978460323963943, 0.059892358231531724, 0],
#  'doc_10444': [0.05978460323963943, 0.059892358231531724, 0],
#  'doc_10446': [0.30309403502886967, 0, 0],
#  'doc_11511': [0.05978460323963943, 0.059892358231531724, 0],
#  'doc_13279': [0.18101449314224158, 0, 0],
#  'doc_13326': [0.11044952123933385, 0, 0],
#  'doc_14448': [0.1253177260215519, 0, 0],
#  'doc_14589': [0.1253177260215519, 0, 0],
#  'doc_14722': [0.1253177260215519, 0, 0],
#  'doc_15739': [0.21021037913292573, 0, 0],
#  'doc_16079': [0.08926742127562598, 0, 0],
#  'doc_16867': [0.5924110684655179, 0, 0],
#  'doc_16912': [0.13033043506241396, 0, 0],
#  'doc_17487': [0.29620553423275897, 0, 0],
#  'doc_17489': [0.10025418081724151, 0, 0],
#  'doc_5': [0, 0.07253630052485509, 0],
#  'doc_19': [0, 0.07019641986276298, 0],
#  'doc_58': [0, 0.05060672129641052, 0],
#  'doc_61': [0, 0.04105828331595571, 0],
#  'doc_72': [0, 0.07253630052485509, 0],
#  'doc_90': [0, 0.0659420913862319, 0],
#  'doc_97': [0, 0.06400261811016625, 0],
#  'doc_98': [0, 0.04352178031491305, 0],
#  'doc_100': [0, 0.4581240033148742, 0],
#  'doc_103': [0, 0.11064859402096539, 0],
#  'doc_136': [0, 0.23525286656709757, 0],
#  'doc_143': [0, 0.046299766292460694, 0],
#  'doc_151': [0, 0.045335187828034425, 0],
#  'doc_153': [0, 0.0870435606298261, 0],
#  'doc_177': [0, 0.3626815026242754, 0],
#  'doc_179': [0, 0.09067037565606885, 0],
#  'doc_180': [0, 0.048357533683236725, 0],
#  'doc_181': [0, 0.05579715424988852, 0],
#  'doc_182': [0, 0.07253630052485509, 0],
#  'doc_186': [0, 0.07376572934731025, 0],
#  'doc_192': [0, 0.0805958894720612, 0],
#  'doc_194': [0, 0.0604469171040459, 0],
#  'doc_202': [0, 0.04730628295099244, 0],
#  'doc_204': [0, 0.05579715424988852, 0],
#  'doc_218': [0, 0.0402979447360306, 0],
#  'doc_219': [0, 0.05307534184745494, 0],
#  'doc_225': [0, 0.04105828331595571, 0],
#  'doc_226': [0, 0.036882864673655126, 0],
#  'doc_231': [0, 0.036268150262427544, 0],
#  'doc_233': [0, 0.12434794375689442, 0],
#  'doc_241': [0, 0.0659420913862319, 0],
#  'doc_244': [0, 0.09067037565606885, 0],
#  'doc_247': [0, 0.08589825062153891, 0],
#  'doc_255': [0, 0.10615068369490988, 0],
#  'doc_261': [0, 0.05579715424988852, 0],
#  'doc_262': [0, 0.038858732424029506, 0],
#  'doc_267': [0, 0.04266841207344416, 0],
#  'doc_270': [0, 0.03509820993138149, 0],
#  'doc_276': [0, 0.14039283972552596, 0],
#  'doc_295': [0, 0.0604469171040459, 0],
#  'doc_298': [0, 0.0402979447360306, 0],
#  'doc_301': [0, 0.0402979447360306, 0],
#  'doc_304': [0, 0.0418478656874164, 0],
#  'doc_308': [0, 0.1611917789441224, 0],
#  'doc_310': [0, 0.28632750207179636, 0],
#  'doc_311': [0, 0.0805958894720612, 0],
#  'doc_316': [0, 0.10702077126617963, 0],
#  'doc_329': [0, 0.07019641986276298, 0],
#  'doc_355': [0, 0.045335187828034425, 0],
#  'doc_356': [0, 0.05307534184745494, 0],
#  'doc_374': [0, 0.03509820993138149, 0],
#  'doc_375': [0, 0.11453100082871855, 0],
#  'doc_381': [0, 0.08942831571557476, 0],
#  'doc_383': [0, 0.09891313707934785, 0],
#  'doc_398': [0, 0.27201112696820656, 0],
#  'doc_403': [0, 0.1208938342080918, 0],
#  'doc_435': [0, 0.03817700027623951, 0],
#  'doc_441': [0, 0.03022345855202295, 0],
#  'doc_443': [0, 0.05881321664177439, 0],
#  'doc_444': [0, 0.03347829254993312, 0],
#  'doc_458': [0, 0.10615068369490988, 0],
#  'doc_463': [0, 0.05726550041435927, 0],
#  'doc_475': [0, 0.1813407513121377, 0],
#  'doc_482': [0, 0.18519906516984277, 0],
#  'doc_485': [0, 0.031086985939223606, 0],
#  'doc_495': [0, 0.1426943616882395, 0],
#  'doc_507': [0, 0.18922513180396977, 0],
#  'doc_519': [0, 0.036882864673655126, 0],
#  'doc_527': [0, 0.27201112696820656, 0],
#  'doc_543': [0, 0.09891313707934785, 0],
#  'doc_554': [0, 0.05579715424988852, 0],
#  'doc_558': [0, 0.0418478656874164, 0],
#  'doc_566': [0, 0.036882864673655126, 0],
#  'doc_570': [0, 0.07635400055247903, 0],
#  'doc_585': [0, 0.14836970561902174, 0],
#  'doc_621': [0, 0.07771746484805901, 0],
#  'doc_628': [0, 0.04945656853967392, 0],
#  'doc_654': [0, 0.05579715424988852, 0],
#  'doc_658': [0, 0.04730628295099244, 0],
#  'doc_669': [0, 0.09891313707934785, 0],
#  'doc_672': [0, 0.13322993973952973, 0],
#  'doc_673': [0, 0.14507260104971018, 0],
#  'doc_678': [0, 0.05579715424988852, 0],
#  'doc_680': [0, 0.11159430849977704, 0],
#  'doc_693': [0, 0.07253630052485509, 0],
#  'doc_701': [0, 0.11762643328354878, 0],
#  'doc_720': [0, 0.10880445078728262, 0],
#  'doc_740': [0, 0.06800278174205164, 0],
#  'doc_758': [0, 0.1673914627496656, 0],
#  'doc_760': [0, 0.07253630052485509, 0],
#  'doc_764': [0, 0.04730628295099244, 0],
#  'doc_768': [0, 0.05881321664177439, 0],
#  'doc_777': [0, 0.03567359042205988, 0],
#  'doc_778': [0, 0.0805958894720612, 0],
#  'doc_781': [0, 0.13600556348410328, 0],
#  'doc_830': [0, 0.07019641986276298, 0],
#  'doc_847': [0, 0.04730628295099244, 0],
#  'doc_853': [0, 0.07253630052485509, 0],
#  'doc_856': [0, 0.05881321664177439, 0],
#  'doc_860': [0, 0.12434794375689442, 0],
#  'doc_861': [0, 0.10702077126617963, 0],
#  'doc_862': [0, 0.03347829254993312, 0],
#  'doc_896': [0, 0.036882864673655126, 0],
#  'doc_901': [0, 0.1208938342080918, 0],
#  'doc_904': [0, 0.0659420913862319, 0],
#  'doc_907': [0, 0.06800278174205164, 0],
#  'doc_937': [0, 0.0402979447360306, 0],
#  'doc_941': [0, 0.11657619727208852, 0],
#  'doc_981': [0, 0.06800278174205164, 0],
#  'doc_984': [0, 0.19200785433049877, 0],
#  'doc_1001': [0, 0.14039283972552596, 0],
#  'doc_1003': [0, 0.0836957313748328, 0],
#  'doc_1006': [0, 0.04945656853967392, 0],
#  'doc_1012': [0, 0.036882864673655126, 0],
#  'doc_1046': [0, 0.0604469171040459, 0],
#  'doc_1048': [0, 0.0070196419862762986, 0],
#  'doc_1052': [0, 0.037518776133545734, 0],
#  'doc_1053': [0, 0.1299157621340688, 0],
#  'doc_1055': [0, 0.04105828331595571, 0],
#  'doc_1066': [0, 0.31086985939223605, 0],
#  'doc_1068': [0, 0.13600556348410328, 0],
#  'doc_1084': [0, 0.24869588751378885, 0],
#  'doc_1096': [0, 0.11453100082871855, 0],
#  'doc_1104': [0, 0.08589825062153891, 0],
#  'doc_1127': [0, 0.030649141066840177, 0],
#  'doc_1134': [0, 0.0836957313748328, 0],
#  'doc_1147': [0, 0.03400139087102582, 0],
#  'doc_1152': [0, 0.06400261811016625, 0],
#  'doc_1160': [0, 0.1318841827724638, 0],
#  'doc_1178': [0, 0.07134718084411976, 0],
#  'doc_1183': [0, 0.03297104569311595, 0],
#  'doc_1192': [0, 0.0659420913862319, 0],
#  'doc_1208': [0, 0.1813407513121377, 0],
#  'doc_1258': [0, 0.09461256590198489, 0],
#  'doc_1266': [0, 0.05881321664177439, 0],
#  'doc_1270': [0, 0.045335187828034425, 0],
#  'doc_1308': [0, 0.10880445078728262, 0],
#  'doc_1313': [0, 0.0324789405335172, 0],
#  'doc_1317': [0, 0.12317484994786712, 0],
#  'doc_1333': [0, 0.09067037565606885, 0],
#  'doc_1339': [0, 0.037518776133545734, 0],
#  'doc_1345': [0, 0.03567359042205988, 0],
#  'doc_1360': [0, 0.05060672129641052, 0],
#  'doc_1366': [0, 0.25108719412449837, 0],
#  'doc_1370': [0, 0.1673914627496656, 0],
#  'doc_1372': [0, 0.1813407513121377, 0],
#  'doc_1395': [0, 0.06342860359796745, 0],
#  'doc_1402': [0, 0.10200417261307745, 0],
#  'doc_1409': [0, 0.02653767092372747, 0],
#  'doc_1475': [0, 0.0649578810670344, 0],
#  'doc_1479': [0, 0.07253630052485509, 0],
#  'doc_1510': [0, 0.048357533683236725, 0],
#  'doc_1512': [0, 0.11657619727208852, 0],
#  'doc_1514': [0, 0.07253630052485509, 0],
#  'doc_1518': [0, 0.06400261811016625, 0],
#  'doc_1520': [0, 0.07771746484805901, 0],
#  'doc_1556': [0, 0.09891313707934785, 0],
#  'doc_1561': [0, 0.045335187828034425, 0],
#  'doc_1565': [0, 0.05579715424988852, 0],
#  'doc_1576': [0, 0.10200417261307745, 0],
#  'doc_1595': [0, 0.05579715424988852, 0],
#  'doc_1599': [0, 0.09259953258492139, 0],
#  'doc_1609': [0, 0.07503755226709147, 0],
#  'doc_1613': [0, 0.09600392716524939, 0],
#  'doc_1624': [0, 0.038858732424029506, 0],
#  'doc_1635': [0, 0.05060672129641052, 0],
#  'doc_1639': [0, 0.03454109548802623, 0],
#  'doc_1640': [0, 0.07253630052485509, 0],
#  'doc_1647': [0, 0.07019641986276298, 0],
#  'doc_1664': [0, 0.10880445078728262, 0],
#  'doc_1690': [0, 0.045335187828034425, 0],
#  'doc_1705': [0, 0.029406608320887196, 0],
#  'doc_1723': [0, 0.04266841207344416, 0],
#  'doc_1724': [0, 0.03347829254993312, 0],
#  'doc_1729': [0, 0.05307534184745494, 0],
#  'doc_1731': [0, 0.04266841207344416, 0],
#  'doc_1733': [0, 0.026865296490687068, 0],
#  'doc_1736': [0, 0.05060672129641052, 0],
#  'doc_1737': [0, 0.06400261811016625, 0],
#  'doc_1741': [0, 0.045335187828034425, 0],
#  'doc_1764': [0, 0.04266841207344416, 0],
#  'doc_1771': [0, 0.06217397187844721, 0],
#  'doc_1774': [0, 0.0659420913862319, 0],
#  'doc_1775': [0, 0.1813407513121377, 0],
#  'doc_1783': [0, 0.03817700027623951, 0],
#  'doc_1789': [0, 0.1813407513121377, 0],
#  'doc_1803': [0, 0.07376572934731025, 0],
#  'doc_1804': [0, 0.05726550041435927, 0],
#  'doc_1808': [0, 0.05060672129641052, 0],
#  'doc_1830': [0, 0.07376572934731025, 0],
#  'doc_1837': [0, 0.09891313707934785, 0],
#  'doc_1853': [0, 0.0659420913862319, 0],
#  'doc_1861': [0, 0.03817700027623951, 0],
#  'doc_1865': [0, 0.05060672129641052, 0],
#  'doc_1867': [0, 0.14836970561902174, 0],
#  'doc_1872': [0, 0.07253630052485509, 0],
#  'doc_1883': [0, 0.05440222539364131, 0],
#  'doc_1889': [0, 0.03509820993138149, 0],
#  'doc_1903': [0, 0.03022345855202295, 0],
#  'doc_1907': [0, 0.1611917789441224, 0],
#  'doc_1918': [0, 0.05579715424988852, 0],
#  'doc_1939': [0, 0.06908219097605246, 0],
#  'doc_1942': [0, 0.14039283972552596, 0],
#  'doc_1945': [0, 0.11657619727208852, 0],
#  'doc_1950': [0, 0.14703304160443598, 0],
#  'doc_1953': [0, 0.1318841827724638, 0],
#  'doc_1966': [0, 0.15543492969611802, 0],
#  'doc_1969': [0, 0.09461256590198489, 0],
#  'doc_1998': [0, 0.04105828331595571, 0],
#  'doc_2003': [0, 0.12317484994786712, 0],
#  'doc_2012': [0, 0.0659420913862319, 0],
#  'doc_2020': [0, 0.07376572934731025, 0],
#  'doc_2031': [0, 0.15543492969611802, 0],
#  'doc_2040': [0, 0.07134718084411976, 0],
#  'doc_2048': [0, 0.04105828331595571, 0],
#  'doc_2051': [0, 0.1740871212596522, 0],
#  'doc_2083': [0, 0.05726550041435927, 0],
#  'doc_2085': [0, 0.013686094438651904, 0],
#  'doc_2095': [0, 0.03454109548802623, 0],
#  'doc_2101': [0, 0.10880445078728262, 0],
#  'doc_2111': [0, 0.08589825062153891, 0],
#  'doc_2118': [0, 0.06217397187844721, 0],
#  'doc_2130': [0, 0.0659420913862319, 0.064477735718568],
#  'doc_2147': [0, 0.05440222539364131, 0],
#  'doc_2152': [0, 0.11064859402096539, 0],
#  'doc_2157': [0, 0.09461256590198489, 0],
#  'doc_2178': [0, 0.14507260104971018, 0],
#  'doc_2181': [0, 0.05060672129641052, 0],
#  'doc_2189': [0, 0.09067037565606885, 0],
#  'doc_2207': [0, 0.05307534184745494, 0],
#  'doc_2222': [0, 0.0805958894720612, 0],
#  'doc_2224': [0, 0.1318841827724638, 0],
#  'doc_2237': [0, 0.09194742320052053, 0],
#  'doc_2238': [0, 0.1813407513121377, 0],
#  'doc_2245': [0, 0.14703304160443598, 0],
#  'doc_2272': [0, 0.0974368216005516, 0],
#  'doc_2279': [0, 0.10362328646407869, 0],
#  'doc_2280': [0, 0.02653767092372747, 0],
#  'doc_2282': [0, 0.046299766292460694, 0],
#  'doc_2287': [0, 0.11159430849977704, 0],
#  'doc_2295': [0, 0.0659420913862319, 0],
#  'doc_2302': [0, 0.04440997991317658, 0],
#  'doc_2303': [0, 0.4581240033148742, 0],
#  'doc_2329': [0, 0.061298282133680354, 0],
#  'doc_2337': [0, 0.05579715424988852, 0],
#  'doc_2339': [0, 0.0649578810670344, 0],
#  'doc_2359': [0, 0.06400261811016625, 0],
#  'doc_2365': [0, 0.07253630052485509, 0],
#  'doc_2368': [0, 0.0604469171040459, 0],
#  'doc_2372': [0, 0.11453100082871855, 0],
#  'doc_2376': [0, 0.22318861699955408, 0],
#  'doc_2377': [0, 0.11762643328354878, 0],
#  'doc_2380': [0, 0.03567359042205988, 0],
#  'doc_2389': [0, 0.036268150262427544, 0],
#  'doc_2410': [0, 0.1740871212596522, 0],
#  'doc_2424': [0, 0.03567359042205988, 0],
#  'doc_2427': [0, 0.29014520209942035, 0],
#  'doc_2436': [0, 0.10702077126617963, 0],
#  'doc_2442': [0, 0.036268150262427544, 0],
#  'doc_2449': [0, 0.04266841207344416, 0],
#  'doc_2464': [0, 0.1673914627496656, 0],
#  'doc_2468': [0, 0.032001309055083124, 0],
#  'doc_2481': [0, 0.03817700027623951, 0],
#  'doc_2494': [0, 0.03347829254993312, 0],
#  'doc_2495': [0, 0.11762643328354878, 0],
#  'doc_2532': [0, 0.045335187828034425, 0],
#  'doc_2545': [0, 0.05579715424988852, 0],
#  'doc_2553': [0, 0.1261500878693132, 0],
#  'doc_2554': [0, 0.11064859402096539, 0],
#  'doc_2561': [0, 0.048357533683236725, 0],
#  'doc_2590': [0, 0.1318841827724638, 0],
#  'doc_2593': [0, 0.11762643328354878, 0],
#  'doc_2611': [0, 0.045335187828034425, 0],
#  'doc_2663': [0, 0.03567359042205988, 0],
#  'doc_2665': [0, 0.0402979447360306, 0],
#  'doc_2668': [0, 0.14507260104971018, 0],
#  'doc_2670': [0, 0.029809438571858252, 0],
#  'doc_2673': [0, 0.029809438571858252, 0],
#  'doc_2702': [0, 0.05579715424988852, 0],
#  'doc_2714': [0, 0.08160333809046197, 0],
#  'doc_2723': [0, 0.05440222539364131, 0],
#  'doc_2730': [0, 0.1813407513121377, 0],
#  'doc_2734': [0, 0.036268150262427544, 0],
#  'doc_2736': [0, 0.07253630052485509, 0],
#  'doc_2740': [0, 0.07771746484805901, 0],
#  'doc_2751': [0, 0.0870435606298261, 0],
#  'doc_2777': [0, 0.10880445078728262, 0],
#  'doc_2782': [0, 0.1813407513121377, 0],
#  'doc_2789': [0, 0.09326095781767083, 0],
#  'doc_2801': [0, 0.07635400055247903, 0],
#  'doc_2804': [0, 0.046299766292460694, 0],
#  'doc_2813': [0, 0.051811643232039344, 0],
#  'doc_2816': [0, 0.05579715424988852, 0],
#  'doc_2841': [0, 0.07253630052485509, 0],
#  'doc_2843': [0, 0.10880445078728262, 0],
#  'doc_2844': [0, 0.1208938342080918, 0],
#  'doc_2858': [0, 0.045335187828034425, 0],
#  'doc_2867': [0, 0.07134718084411976, 0],
#  'doc_2870': [0, 0.06217397187844721, 0],
#  'doc_2872': [0, 0.11159430849977704, 0],
#  'doc_2889': [0, 0.21404154253235927, 0],
#  'doc_2908': [0, 0.14836970561902174, 0],
#  'doc_2929': [0, 0.07503755226709147, 0],
#  'doc_2946': [0, 0.11762643328354878, 0],
#  'doc_2957': [0, 0.04105828331595571, 0],
#  'doc_2959': [0, 0.038858732424029506, 0],
#  'doc_2960': [0, 0.11159430849977704, 0],
#  'doc_2967': [0, 0.14039283972552596, 0],
#  'doc_2983': [0, 0.0315375219673283, 0],
#  'doc_3004': [0, 0.06800278174205164, 0],
#  'doc_3011': [0, 0.15543492969611802, 0],
#  'doc_3014': [0, 0.16320667618092394, 0],
#  'doc_3016': [0, 0.04945656853967392, 0],
#  'doc_3029': [0, 0.036268150262427544, 0],
#  'doc_3056': [0, 0.07253630052485509, 0],
#  'doc_3082': [0, 0.0604469171040459, 0],
#  'doc_3083': [0, 0.036268150262427544, 0],
#  'doc_3092': [0, 0.08211656663191141, 0],
#  'doc_3119': [0, 0.061298282133680354, 0],
#  'doc_3128': [0, 0.06400261811016625, 0],
#  'doc_3141': [0, 0.0836957313748328, 0],
#  'doc_3142': [0, 0.0805958894720612, 0],
#  'doc_3145': [0, 0.15543492969611802, 0],
#  'doc_3159': [0, 0.04266841207344416, 0],
#  'doc_3171': [0, 0.09891313707934785, 0],
#  'doc_3173': [0, 0.14039283972552596, 0],
#  'doc_3181': [0, 0.1280052362203325, 0],
#  'doc_3188': [0, 0.09326095781767083, 0],
#  'doc_3193': [0, 0.03347829254993312, 0],
#  'doc_3197': [0, 0.036882864673655126, 0],
#  'doc_3198': [0, 0.07446692449319724, 0],
#  'doc_3201': [0, 0.09259953258492139, 0],
#  'doc_3204': [0, 0.036882864673655126, 0],
#  'doc_3215': [0, 0.0402979447360306, 0],
#  'doc_3218': [0, 0.05726550041435927, 0],
#  'doc_3226': [0, 0.21058925958828895, 0],
#  'doc_3238': [0, 0.07253630052485509, 0],
#  'doc_3243': [0, 0.04266841207344416, 0],
#  'doc_3252': [0, 0.05060672129641052, 0],
#  'doc_3262': [0, 0.046299766292460694, 0],
#  'doc_3276': [0, 0.04352178031491305, 0],
#  'doc_3279': [0, 0.1261500878693132, 0],
#  'doc_3305': [0, 0.06217397187844721, 0],
#  'doc_3326': [0, 0.04945656853967392, 0],
#  'doc_3327': [0, 0.07503755226709147, 0],
#  'doc_3329': [0, 0.05881321664177439, 0],
#  'doc_3343': [0, 0.05579715424988852, 0],
#  'doc_3345': [0, 0.1813407513121377, 0],
#  'doc_3353': [0, 0.07019641986276298, 0],
#  'doc_3365': [0, 0.06800278174205164, 0],
#  'doc_3378': [0, 0.06217397187844721, 0],
#  'doc_3379': [0, 0.09600392716524939, 0],
#  'doc_3383': [0, 0.045335187828034425, 0],
#  'doc_3396': [0, 0.29014520209942035, 0],
#  'doc_3401': [0, 0.07771746484805901, 0],
#  'doc_3403': [0, 0.10362328646407869, 0],
#  'doc_3420': [0, 0.045335187828034425, 0],
#  'doc_3424': [0, 0.12554359706224918, 0],
#  'doc_3429': [0, 0.07019641986276298, 0],
#  'doc_3432': [0, 0.045335187828034425, 0],
#  'doc_3433': [0, 0.09461256590198489, 0],
#  'doc_3450': [0, 0.05060672129641052, 0],
#  'doc_3478': [0, 0.1318841827724638, 0],
#  'doc_3493': [0, 0.051811643232039344, 0],
#  'doc_3496': [0, 0.0402979447360306, 0],
#  'doc_3499': [0, 0.0836957313748328, 0],
#  'doc_3500': [0, 0.030649141066840177, 0],
#  'doc_3505': [0, 0.05440222539364131, 0],
#  'doc_3507': [0, 0.036882864673655126, 0],
#  'doc_3518': [0, 0.045335187828034425, 0],
#  'doc_3526': [0, 0.1280052362203325, 0],
#  'doc_3543': [0, 0.045335187828034425, 0],
#  'doc_3589': [0, 0.05440222539364131, 0],
#  'doc_3618': [0, 0.06217397187844721, 0],
#  'doc_3621': [0, 0.05579715424988852, 0],
#  'doc_3652': [0, 0.06217397187844721, 0],
#  'doc_3665': [0, 0.12554359706224918, 0],
#  'doc_3712': [0, 0.18922513180396977, 0],
#  'doc_3715': [0, 0.1318841827724638, 0],
#  'doc_3722': [0, 0.04440997991317658, 0],
#  'doc_3754': [0, 0.045335187828034425, 0],
#  'doc_3767': [0, 0.05579715424988852, 0],
#  'doc_3769': [0, 0.07503755226709147, 0],
#  'doc_3772': [0, 0.22318861699955408, 0],
#  'doc_3776': [0, 0.05440222539364131, 0],
#  'doc_3794': [0, 0.07019641986276298, 0],
#  'doc_3814': [0, 0.04945656853967392, 0],
#  'doc_3815': [0, 0.09600392716524939, 0],
#  'doc_3841': [0, 0.05060672129641052, 0],
#  'doc_3846': [0, 0.07503755226709147, 0],
#  'doc_3859': [0, 0.026865296490687068, 0],
#  'doc_3867': [0, 0.045335187828034425, 0],
#  'doc_3868': [0, 0.029406608320887196, 0],
#  'doc_3880': [0, 0.07771746484805901, 0],
#  'doc_3884': [0, 0.1208938342080918, 0],
#  'doc_3886': [0, 0.03817700027623951, 0],
#  'doc_3887': [0, 0.048357533683236725, 0],
#  'doc_3889': [0, 0.09461256590198489, 0],
#  'doc_3919': [0, 0.11453100082871855, 0],
#  'doc_3925': [0, 0.03347829254993312, 0],
#  'doc_3926': [0, 0.03347829254993312, 0],
#  'doc_3936': [0, 0.11159430849977704, 0],
#  'doc_3945': [0, 0.11064859402096539, 0],
#  'doc_3948': [0, 0.05726550041435927, 0],
#  'doc_3955': [0, 0.09891313707934785, 0],
#  'doc_3961': [0, 0.06400261811016625, 0],
#  'doc_3963': [0, 0.05579715424988852, 0],
#  'doc_3971': [0, 0.07019641986276298, 0],
#  'doc_3990': [0, 0.014316375103589818, 0],
#  'doc_3997': [0, 0.03817700027623951, 0],
#  'doc_4014': [0, 0.03567359042205988, 0],
#  'doc_4021': [0, 0.07503755226709147, 0],
#  'doc_4042': [0, 0.045335187828034425, 0],
#  'doc_4060': [0, 0.1208938342080918, 0],
#  'doc_4065': [0, 0.036882864673655126, 0],
#  'doc_4079': [0, 0.0315375219673283, 0],
#  'doc_4083': [0, 0.12434794375689442, 0],
#  'doc_4088': [0, 0.0282608963083851, 0],
#  'doc_4111': [0, 0.0402979447360306, 0],
#  'doc_4147': [0, 0.1813407513121377, 0],
#  'doc_4152': [0, 0.09067037565606885, 0],
#  'doc_4162': [0, 0.05440222539364131, 0],
#  'doc_4177': [0, 0.04440997991317658, 0],
#  'doc_4178': [0, 0.12434794375689442, 0],
#  'doc_4184': [0, 0.07771746484805901, 0],
#  'doc_4185': [0, 0.05060672129641052, 0],
#  'doc_4192': [0, 0.08211656663191141, 0],
#  'doc_4217': [0, 0.10880445078728262, 0],
#  'doc_4220': [0, 0.10615068369490988, 0],
#  'doc_4232': [0, 0.07503755226709147, 0],
#  'doc_4263': [0, 0.010772717899730952, 0],
#  'doc_4266': [0, 0.023149883146230347, 0],
#  'doc_4277': [0, 0.07503755226709147, 0],
#  'doc_4279': [0, 0.03509820993138149, 0],
#  'doc_4291': [0, 0.05579715424988852, 0],
#  'doc_4322': [0, 0.09891313707934785, 0],
#  'doc_4335': [0, 0.05307534184745494, 0],
#  'doc_4344': [0, 0.06217397187844721, 0],
#  'doc_4347': [0, 0.1934301347329469, 0],
#  'doc_4362': [0, 0.07635400055247903, 0],
#  'doc_4374': [0, 0.05579715424988852, 0],
#  'doc_4378': [0, 0.0659420913862319, 0],
#  'doc_4380': [0, 0.21760890157456525, 0],
#  'doc_4381': [0, 0.05579715424988852, 0],
#  'doc_4389': [0, 0.11453100082871855, 0],
#  'doc_4401': [0, 0.09259953258492139, 0],
#  'doc_4423': [0, 0.0659420913862319, 0],
#  'doc_4426': [0, 0.04730628295099244, 0],
#  'doc_4436': [0, 0.04105828331595571, 0],
#  'doc_4443': [0, 0.07019641986276298, 0],
#  'doc_4450': [0, 0.0402979447360306, 0],
#  'doc_4462': [0, 0.05579715424988852, 0],
#  'doc_4463': [0, 0.04352178031491305, 0],
#  'doc_4465': [0, 0.11762643328354878, 0],
#  'doc_4474': [0, 0.1813407513121377, 0],
#  'doc_4489': [0, 0.10121344259282104, 0],
#  'doc_4494': [0, 0.051811643232039344, 0],
#  'doc_4505': [0, 0.0402979447360306, 0],
#  'doc_4520': [0, 0.037518776133545734, 0],
#  'doc_4521': [0, 0.11453100082871855, 0],
#  'doc_4526': [0, 0.10362328646407869, 0],
#  'doc_4531': [0, 0.06800278174205164, 0],
#  'doc_4539': [0, 0.16320667618092394, 0],
#  'doc_4551': [0, 0.036882864673655126, 0],
#  'doc_4556': [0, 0.04945656853967392, 0],
#  'doc_4574': [0, 0.0604469171040459, 0],
#  'doc_4580': [0, 0.04105828331595571, 0],
#  'doc_4590': [0, 0.05060672129641052, 0],
#  'doc_4600': [0, 0.05726550041435927, 0],
#  'doc_4606': [0, 0.07771746484805901, 0],
#  'doc_4617': [0, 0.012225219189582318, 0],
#  'doc_4624': [0, 0.03509820993138149, 0],
#  'doc_4627': [0, 0.029809438571858252, 0],
#  'doc_4629': [0, 0.032001309055083124, 0],
#  'doc_4641': [0, 0.07253630052485509, 0],
#  'doc_4643': [0, 0.0974368216005516, 0],
#  'doc_4647': [0, 0.14703304160443598, 0],
#  'doc_4650': [0, 0.0659420913862319, 0],
#  'doc_4655': [0, 0.07253630052485509, 0],
#  'doc_4670': [0, 0.04266841207344416, 0],
#  'doc_4674': [0, 0.13600556348410328, 0],
#  'doc_4677': [0, 0.0805958894720612, 0],
#  'doc_4691': [0, 0.03347829254993312, 0],
#  'doc_4701': [0, 0.06800278174205164, 0],
#  'doc_4724': [0, 0.036882864673655126, 0],
#  'doc_4731': [0, 0.045335187828034425, 0],
#  'doc_4746': [0, 0.1592260255423648, 0],
#  'doc_4749': [0, 0.2417876684161836, 0],
#  'doc_4801': [0, 0.05579715424988852, 0],
#  'doc_4829': [0, 0.15543492969611802, 0],
#  'doc_4836': [0, 0.029406608320887196, 0],
#  'doc_4840': [0, 0.14507260104971018, 0],
#  'doc_4842': [0, 0.23525286656709757, 0],
#  'doc_4850': [0, 0.0659420913862319, 0],
#  'doc_4854': [0, 0.07376572934731025, 0],
#  'doc_4861': [0, 0.1208938342080918, 0],
#  'doc_4867': [0, 0.1978262741586957, 0],
#  'doc_4876': [0, 0.09461256590198489, 0],
#  'doc_4877': [0, 0.12952910808009835, 0],
#  'doc_4879': [0, 0.04266841207344416, 0],
#  'doc_4900': [0, 0.0402979447360306, 0],
#  'doc_4906': [0, 0.14507260104971018, 0],
#  'doc_4916': [0, 0.0324789405335172, 0],
#  'doc_4920': [0, 0.06217397187844721, 0],
#  'doc_4926': [0, 0.06217397187844721, 0],
#  'doc_4927': [0, 0.07503755226709147, 0],
#  'doc_4937': [0, 0.10880445078728262, 0],
#  'doc_4948': [0, 0.06800278174205164, 0],
#  'doc_4955': [0, 0.13889929887738206, 0],
#  'doc_4964': [0, 0.1208938342080918, 0],
#  'doc_4968': [0, 0.036268150262427544, 0],
#  'doc_4974': [0, 0.036882864673655126, 0],
#  'doc_4977': [0, 0.0805958894720612, 0],
#  'doc_4993': [0, 0.06908219097605246, 0],
#  'doc_5028': [0, 0.10880445078728262, 0],
#  'doc_5034': [0, 0.04945656853967392, 0.09671660357785201],
#  'doc_5041': [0, 0.09461256590198489, 0],
#  'doc_5051': [0, 0.1611917789441224, 0],
#  'doc_5073': [0, 0.048357533683236725, 0],
#  'doc_5076': [0, 0.0324789405335172, 0],
#  'doc_5082': [0, 0.04266841207344416, 0],
#  'doc_5084': [0, 0.07019641986276298, 0],
#  'doc_5125': [0, 0.11453100082871855, 0],
#  'doc_5129': [0, 0.04730628295099244, 0],
#  'doc_5143': [0, 0.05440222539364131, 0],
#  'doc_5155': [0, 0.037518776133545734, 0],
#  'doc_5160': [0, 0.0315375219673283, 0],
#  'doc_5163': [0, 0.10826313511172402, 0],
#  'doc_5168': [0, 0.18652191563534165, 0],
#  'doc_5174': [0, 0.0604469171040459, 0],
#  'doc_5177': [0, 0.032001309055083124, 0],
#  'doc_5183': [0, 0.05726550041435927, 0],
#  'doc_5197': [0, 0.0659420913862319, 0],
#  'doc_5208': [0, 0.07253630052485509, 0],
#  'doc_5226': [0, 0.05881321664177439, 0],
#  'doc_5233': [0, 0.10880445078728262, 0],
#  'doc_5244': [0, 0.0659420913862319, 0],
#  'doc_5261': [0, 0.15543492969611802, 0],
#  'doc_5272': [0, 0.06217397187844721, 0],
#  'doc_5276': [0, 0.0805958894720612, 0],
#  'doc_5281': [0, 0.048357533683236725, 0],
#  'doc_5284': [0, 0.036882864673655126, 0],
#  'doc_5295': [0, 0.1673914627496656, 0],
#  'doc_5300': [0, 0.031086985939223606, 0],
#  'doc_5307': [0, 0.0870435606298261, 0],
#  'doc_5311': [0, 0.0402979447360306, 0],
#  'doc_5315': [0, 0.07019641986276298, 0],
#  'doc_5325': [0, 0.06400261811016625, 0],
#  'doc_5329': [0, 0.06400261811016625, 0],
#  'doc_5333': [0, 0.1673914627496656, 0],
#  'doc_5341': [0, 0.0659420913862319, 0],
#  'doc_5359': [0, 0.04352178031491305, 0],
#  'doc_5367': [0, 0.05726550041435927, 0],
#  'doc_5372': [0, 0.046299766292460694, 0],
#  'doc_5374': [0, 0.13322993973952973, 0],
#  'doc_5375': [0, 0.1299157621340688, 0],
#  'doc_5386': [0, 0.0324789405335172, 0],
#  'doc_5389': [0, 0.09891313707934785, 0],
#  'doc_5399': [0, 0.07019641986276298, 0],
#  'doc_5402': [0, 0.03022345855202295, 0],
#  'doc_5406': [0, 0.0659420913862319, 0],
#  'doc_5417': [0, 0.09891313707934785, 0],
#  'doc_5421': [0, 0.038858732424029506, 0],
#  'doc_5430': [0, 0.03567359042205988, 0],
#  'doc_5445': [0, 0.10880445078728262, 0],
#  'doc_5452': [0, 0.13600556348410328, 0],
#  'doc_5454': [0, 0.0064668321418890114, 0.012646450393537855],
#  'doc_5461': [0, 0.03956525483173914, 0],
#  'doc_5464': [0, 0.07503755226709147, 0],
#  'doc_5471': [0, 0.07253630052485509, 0],
#  'doc_5474': [0, 0.06217397187844721, 0],
#  'doc_5500': [0, 0.11453100082871855, 0],
#  'doc_5503': [0, 0.045335187828034425, 0],
#  'doc_5509': [0, 0.036882864673655126, 0],
#  'doc_5516': [0, 0.06217397187844721, 0],
#  'doc_5521': [0, 0.0402979447360306, 0],
#  'doc_5523': [0, 0.1413044815419255, 0],
#  'doc_5531': [0, 0.051811643232039344, 0],
#  'doc_5551': [0, 0.10043487764979935, 0],
#  'doc_5557': [0, 0.05307534184745494, 0],
#  'doc_5562': [0, 0.04266841207344416, 0],
#  'doc_5568': [0, 0.09067037565606885, 0],
#  'doc_5573': [0, 0.06400261811016625, 0],
#  'doc_5578': [0, 0.07503755226709147, 0],
#  'doc_5581': [0, 0.04266841207344416, 0],
#  'doc_5585': [0, 0.10880445078728262, 0],
#  'doc_5587': [0, 0.05579715424988852, 0],
#  'doc_5590': [0, 0.051811643232039344, 0],
#  'doc_5606': [0, 0.05726550041435927, 0],
#  'doc_5618': [0, 0.0649578810670344, 0],
#  'doc_5627': [0, 0.1673914627496656, 0],
#  'doc_5641': [0, 0.09891313707934785, 0],
#  'doc_5642': [0, 0.036268150262427544, 0],
#  'doc_5645': [0, 0.04168752903727303, 0],
#  'doc_5649': [0, 0.05579715424988852, 0],
#  'doc_5650': [0, 0.07771746484805901, 0],
#  'doc_5651': [0, 0.1611917789441224, 0],
#  'doc_5655': [0, 0.08533682414688833, 0],
#  'doc_5660': [0, 0.21760890157456525, 0],
#  'doc_5664': [0, 0.10362328646407869, 0],
#  'doc_5666': [0, 0.014316375103589818, 0],
#  'doc_5693': [0, 0.031086985939223606, 0],
#  'doc_5694': [0, 0.0659420913862319, 0],
#  'doc_5697': [0, 0.1673914627496656, 0],
#  'doc_5700': [0, 0.1280052362203325, 0],
#  'doc_5703': [0, 0.011699403310460498, 0],
#  'doc_5709': [0, 0.07253630052485509, 0],
#  'doc_5720': [0, 0.1186957644952174, 0],
#  'doc_5721': [0, 0.0649578810670344, 0],
#  'doc_5727': [0, 0.18922513180396977, 0],
#  'doc_5735': [0, 0.0870435606298261, 0],
#  'doc_5737': [0, 0.03817700027623951, 0],
#  'doc_5748': [0, 0.05579715424988852, 0],
#  'doc_5763': [0, 0.06695658509986624, 0],
#  'doc_5769': [0, 0.21230136738981975, 0],
#  'doc_5778': [0, 0.07376572934731025, 0],
#  'doc_5779': [0, 0.0604469171040459, 0],
#  'doc_5781': [0, 0.045335187828034425, 0],
#  'doc_5805': [0, 0.12434794375689442, 0],
#  'doc_5806': [0, 0.035968413483399214, 0],
#  'doc_5808': [0, 0.045335187828034425, 0],
#  'doc_5827': [0, 0.032001309055083124, 0],
#  'doc_5828': [0, 0.03347829254993312, 0],
#  'doc_5834': [0, 0.05579715424988852, 0],
#  'doc_5842': [0, 0.1318841827724638, 0],
#  'doc_5849': [0, 0.14039283972552596, 0],
#  'doc_5857': [0, 0.05579715424988852, 0],
#  'doc_5858': [0, 0.0659420913862319, 0],
#  'doc_5863': [0, 0.07134718084411976, 0],
#  'doc_5870': [0, 0.11064859402096539, 0],
#  'doc_5875': [0, 0.12259656426736071, 0],
#  'doc_5876': [0, 0.07253630052485509, 0],
#  'doc_5887': [0, 0.10615068369490988, 0],
#  'doc_5890': [0, 0.1280052362203325, 0],
#  'doc_5894': [0, 0.036268150262427544, 0],
#  'doc_5899': [0, 0.1592260255423648, 0],
#  'doc_5917': [0, 0.21058925958828895, 0],
#  'doc_5941': [0, 0.0659420913862319, 0],
#  'doc_5946': [0, 0.04730628295099244, 0],
#  'doc_5953': [0, 0.05307534184745494, 0],
#  'doc_5954': [0, 0.03347829254993312, 0],
#  'doc_5956': [0, 0.04440997991317658, 0],
#  'doc_5958': [0, 0.10362328646407869, 0],
#  'doc_5967': [0, 0.01576876098366415, 0],
#  'doc_5974': [0, 0.14507260104971018, 0],
#  'doc_6002': [0, 0.03022345855202295, 0],
#  'doc_6007': [0, 0.13600556348410328, 0],
#  'doc_6014': [0, 0.20242688518564209, 0],
#  'doc_6018': [0, 0.11762643328354878, 0],
#  'doc_6031': [0, 0.046299766292460694, 0],
#  'doc_6042': [0, 0.045335187828034425, 0],
#  'doc_6049': [0, 0.04945656853967392, 0],
#  'doc_6062': [0, 0.09067037565606885, 0],
#  'doc_6063': [0, 0.07253630052485509, 0],
#  'doc_6114': [0, 0.0836957313748328, 0],
#  'doc_6117': [0, 0.07134718084411976, 0],
#  'doc_6131': [0, 0.1475314586946205, 0],
#  'doc_6132': [0, 0.04105828331595571, 0],
#  'doc_6140': [0, 0.21760890157456525, 0],
#  'doc_6146': [0, 0.10880445078728262, 0],
#  'doc_6151': [0, 0.15826101932695655, 0],
#  'doc_6152': [0, 0.07076712246327325, 0],
#  'doc_6164': [0, 0.09891313707934785, 0],
#  'doc_6179': [0, 0.06400261811016625, 0],
#  'doc_6190': [0, 0.03297104569311595, 0],
#  'doc_6195': [0, 0.1280052362203325, 0],
#  'doc_6196': [0, 0.03454109548802623, 0],
#  'doc_6199': [0, 0.10362328646407869, 0],
#  'doc_6200': [0, 0.06400261811016625, 0],
#  'doc_6214': [0, 0.03567359042205988, 0],
#  'doc_6216': [0, 0.03956525483173914, 0],
#  'doc_6219': [0, 0.038858732424029506, 0],
#  'doc_6231': [0, 0.1186957644952174, 0],
#  'doc_6241': [0, 0.07771746484805901, 0],
#  'doc_6249': [0, 0.0402979447360306, 0],
#  'doc_6268': [0, 0.10880445078728262, 0],
#  'doc_6269': [0, 0.0630750439346566, 0],
#  'doc_6277': [0, 0.2637683655449276, 0],
#  'doc_6282': [0, 0.06400261811016625, 0],
#  'doc_6284': [0, 0.2417876684161836, 0],
#  'doc_6286': [0, 0.15182016388923156, 0],
#  'doc_6287': [0, 0.0805958894720612, 0],
#  'doc_6291': [0, 0.07376572934731025, 0],
#  'doc_6295': [0, 0.0282608963083851, 0],
#  'doc_6302': [0, 0.05726550041435927, 0],
#  'doc_6304': [0, 0.04105828331595571, 0],
#  'doc_6320': [0, 0.07503755226709147, 0],
#  'doc_6326': [0, 0.030649141066840177, 0],
#  'doc_6334': [0, 0.05060672129641052, 0],
#  'doc_6342': [0, 0.21760890157456525, 0],
#  'doc_6345': [0, 0.031086985939223606, 0],
#  'doc_6349': [0, 0.037518776133545734, 0],
#  'doc_6355': [0, 0.1813407513121377, 0],
#  'doc_6362': [0, 0.08533682414688833, 0],
#  'doc_6363': [0, 0.09891313707934785, 0],
#  'doc_6365': [0, 0.0659420913862319, 0],
#  'doc_6366': [0, 0.06800278174205164, 0],
#  'doc_6375': [0, 0.018286462317190357, 0],
#  'doc_6377': [0, 0.07503755226709147, 0],
#  'doc_6391': [0, 0.11453100082871855, 0],
#  'doc_6393': [0, 0.048357533683236725, 0],
#  'doc_6399': [0, 0.03347829254993312, 0],
#  'doc_6402': [0, 0.15543492969611802, 0],
#  'doc_6409': [0, 0.06217397187844721, 0],
#  'doc_6425': [0, 0.12259656426736071, 0],
#  'doc_6438': [0, 0.05579715424988852, 0],
#  'doc_6457': [0, 0.1280052362203325, 0],
#  'doc_6492': [0, 0.07253630052485509, 0],
#  'doc_6496': [0, 0.03567359042205988, 0],
#  'doc_6522': [0, 0.05440222539364131, 0],
#  'doc_6523': [0, 0.0402979447360306, 0],
#  'doc_6534': [0, 0.045335187828034425, 0],
#  'doc_6542': [0, 0.09891313707934785, 0],
#  'doc_6556': [0, 0.10880445078728262, 0],
#  'doc_6565': [0, 0.0315375219673283, 0],
#  'doc_6566': [0, 0.18922513180396977, 0],
#  'doc_6583': [0, 0.07019641986276298, 0],
#  'doc_6590': [0, 0.03400139087102582, 0],
#  'doc_6593': [0, 0.10615068369490988, 0],
#  'doc_6596': [0, 0.051811643232039344, 0],
#  'doc_6597': [0, 0.12317484994786712, 0],
#  'doc_6608': [0, 0.05579715424988852, 0],
#  'doc_6617': [0, 0.13600556348410328, 0],
#  'doc_6620': [0, 0.05726550041435927, 0],
#  'doc_6633': [0, 0.07019641986276298, 0],
#  'doc_6666': [0, 0.0315375219673283, 0],
#  'doc_6669': [0, 0.09067037565606885, 0],
#  'doc_6687': [0, 0.09891313707934785, 0],
#  'doc_6696': [0, 0.07376572934731025, 0],
#  'doc_6706': [0, 0.07635400055247903, 0],
#  'doc_6716': [0, 0.11762643328354878, 0],
#  'doc_6749': [0, 0.05060672129641052, 0],
#  'doc_6754': [0, 0.07771746484805901, 0],
#  'doc_6792': [0, 0.06217397187844721, 0],
#  'doc_6793': [0, 0.07635400055247903, 0],
#  'doc_6814': [0, 0.07253630052485509, 0],
#  'doc_6820': [0, 0.1673914627496656, 0],
#  'doc_6823': [0, 0.07253630052485509, 0],
#  'doc_6842': [0, 0.1673914627496656, 0],
#  'doc_6858': [0, 0.14507260104971018, 0],
#  'doc_6892': [0, 0.06217397187844721, 0],
#  'doc_6893': [0, 0.032001309055083124, 0],
#  'doc_6927': [0, 0.21760890157456525, 0],
#  'doc_6937': [0, 0.07253630052485509, 0],
#  'doc_6944': [0, 0.13600556348410328, 0],
#  'doc_6950': [0, 0.06400261811016625, 0],
#  'doc_6960': [0, 0.07134718084411976, 0],
#  'doc_6963': [0, 0.1208938342080918, 0],
#  'doc_6964': [0, 0.03509820993138149, 0],
#  'doc_6966': [0, 0.1740871212596522, 0],
#  'doc_6967': [0, 0.03454109548802623, 0],
#  'doc_6973': [0, 0.05881321664177439, 0],
#  'doc_6978': [0, 0.04730628295099244, 0],
#  'doc_6987': [0, 0.03454109548802623, 0],
#  'doc_6988': [0, 0.045335187828034425, 0],
#  'doc_6998': [0, 0.0870435606298261, 0],
#  'doc_6999': [0, 0.06400261811016625, 0],
#  'doc_7004': [0, 0.10880445078728262, 0],
#  'doc_7021': [0, 0.14039283972552596, 0],
#  'doc_7022': [0, 0.1813407513121377, 0],
#  'doc_7031': [0, 0.12317484994786712, 0],
#  'doc_7041': [0, 0.1318841827724638, 0],
#  'doc_7042': [0, 0.04352178031491305, 0],
#  'doc_7056': [0, 0.04105828331595571, 0],
#  'doc_7061': [0, 0.09891313707934785, 0],
#  'doc_7078': [0, 0.05726550041435927, 0],
#  'doc_7080': [0, 0.04730628295099244, 0],
#  'doc_7082': [0, 0.05881321664177439, 0],
#  'doc_7085': [0, 0.061298282133680354, 0],
#  'doc_7088': [0, 0.030505920781481108, 0],
#  'doc_7089': [0, 0.051811643232039344, 0],
#  'doc_7090': [0, 0.045335187828034425, 0],
#  'doc_7095': [0, 0.030649141066840177, 0],
#  'doc_7104': [0, 0.1318841827724638, 0],
#  'doc_7110': [0, 0.09461256590198489, 0],
#  'doc_7114': [0, 0.0604469171040459, 0],
#  'doc_7117': [0, 0.1208938342080918, 0],
#  'doc_7121': [0, 0.05579715424988852, 0],
#  'doc_7137': [0, 0.038858732424029506, 0],
#  'doc_7142': [0, 0.0836957313748328, 0],
#  'doc_7171': [0, 0.1280052362203325, 0],
#  'doc_7174': [0, 0.03454109548802623, 0],
#  'doc_7187': [0, 0.13600556348410328, 0],
#  'doc_7231': [0, 0.03400139087102582, 0],
#  'doc_7233': [0, 0.038858732424029506, 0],
#  'doc_7235': [0, 0.2040083452261549, 0],
#  'doc_7247': [0, 0.11657619727208852, 0],
#  'doc_7248': [0, 0.1318841827724638, 0],
#  'doc_7249': [0, 0.21058925958828895, 0],
#  'doc_7250': [0, 0.07376572934731025, 0],
#  'doc_7256': [0, 0.029014520209942034, 0],
#  'doc_7263': [0, 0.0604469171040459, 0],
#  'doc_7264': [0, 0.15543492969611802, 0],
#  'doc_7287': [0, 0.06217397187844721, 0],
#  'doc_7288': [0, 0.04945656853967392, 0],
#  'doc_7301': [0, 0.09891313707934785, 0],
#  'doc_7306': [0, 0.04730628295099244, 0],
#  'doc_7316': [0, 0.09891313707934785, 0],
#  'doc_7325': [0, 0.12434794375689442, 0],
#  'doc_7333': [0, 0.051811643232039344, 0],
#  'doc_7335': [0, 0.05579715424988852, 0],
#  'doc_7344': [0, 0.21230136738981975, 0],
#  'doc_7383': [0, 0.03956525483173914, 0],
#  'doc_7384': [0, 0.029406608320887196, 0],
#  'doc_7386': [0, 0.1208938342080918, 0],
#  'doc_7394': [0, 0.051811643232039344, 0],
#  'doc_7398': [0, 0.13600556348410328, 0],
#  'doc_7401': [0, 0.27201112696820656, 0],
#  'doc_7405': [0, 0.0659420913862319, 0],
#  'doc_7470': [0, 0.05060672129641052, 0],
#  'doc_7485': [0, 0.05060672129641052, 0],
#  'doc_7491': [0, 0.051811643232039344, 0],
#  'doc_7521': [0, 0.06217397187844721, 0],
#  'doc_7539': [0, 0.11762643328354878, 0],
#  'doc_7551': [0, 0.10200417261307745, 0],
#  'doc_7563': [0, 0.31086985939223605, 0],
#  'doc_7580': [0, 0.03509820993138149, 0],
#  'doc_7641': [0, 0.04105828331595571, 0],
#  'doc_7646': [0, 0.06908219097605246, 0],
#  'doc_7656': [0, 0.05307534184745494, 0],
#  'doc_7675': [0, 0.04730628295099244, 0],
#  'doc_7721': [0, 0.0805958894720612, 0],
#  'doc_7761': [0, 0.05822311747814455, 0],
#  'doc_7764': [0, 0.036268150262427544, 0],
#  'doc_7773': [0, 0.07635400055247903, 0],
#  'doc_7777': [0, 0.036882864673655126, 0],
#  'doc_7799': [0, 0.05579715424988852, 0],
#  'doc_7821': [0, 0.031086985939223606, 0],
#  'doc_7828': [0, 0.10880445078728262, 0],
#  'doc_7829': [0, 0.07134718084411976, 0],
#  'doc_7841': [0, 0.0649578810670344, 0],
#  'doc_7845': [0, 0.0659420913862319, 0],
#  'doc_7863': [0, 0.05440222539364131, 0],
#  'doc_7869': [0, 0.036268150262427544, 0],
#  'doc_7871': [0, 0.09326095781767083, 0],
#  'doc_7873': [0, 0.0836957313748328, 0],
#  'doc_7878': [0, 0.06400261811016625, 0],
#  'doc_7922': [0, 0.0870435606298261, 0],
#  'doc_7939': [0, 0.11762643328354878, 0],
#  'doc_7958': [0, 0.03022345855202295, 0],
#  'doc_7959': [0, 0.05307534184745494, 0],
#  'doc_7963': [0, 0.13889929887738206, 0],
#  'doc_7964': [0, 0.061298282133680354, 0],
#  'doc_7970': [0, 0.07771746484805901, 0],
#  'doc_7979': [0, 0.0402979447360306, 0],
#  'doc_7980': [0, 0.045335187828034425, 0],
#  'doc_7983': [0, 0.10362328646407869, 0],
#  'doc_7984': [0, 0.15270800110495805, 0],
#  'doc_7994': [0, 0.1673914627496656, 0],
#  'doc_8002': [0, 0.03817700027623951, 0],
#  'doc_8007': [0, 0.07019641986276298, 0],
#  'doc_8012': [0, 0.045335187828034425, 0],
#  'doc_8021': [0, 0.15007510453418293, 0],
#  'doc_8038': [0, 0.1813407513121377, 0],
#  'doc_8041': [0, 0.04730628295099244, 0],
#  'doc_8042': [0, 0.07019641986276298, 0],
#  'doc_8054': [0, 0.07503755226709147, 0],
#  'doc_8057': [0, 0.07503755226709147, 0],
#  'doc_8064': [0, 0.11159430849977704, 0],
#  'doc_8073': [0, 0.048573415530036884, 0],
#  'doc_8077': [0, 0.0836957313748328, 0],
#  'doc_8081': [0, 0.05881321664177439, 0],
#  'doc_8085': [0, 0.05943100253086866, 0],
#  'doc_8091': [0, 0.04945656853967392, 0],
#  'doc_8096': [0, 0.07635400055247903, 0],
#  'doc_8097': [0, 0.27201112696820656, 0],
#  'doc_8099': [0, 0.03956525483173914, 0],
#  'doc_8110': [0, 0.1813407513121377, 0],
#  'doc_8119': [0, 0.05440222539364131, 0],
#  'doc_8123': [0, 0.12434794375689442, 0],
#  'doc_8128': [0, 0.10880445078728262, 0],
#  'doc_8137': [0, 0.0402979447360306, 0],
#  'doc_8165': [0, 0.026865296490687068, 0],
#  'doc_8203': [0, 0.05579715424988852, 0],
#  'doc_8208': [0, 0.07253630052485509, 0],
#  'doc_8210': [0, 0.036882864673655126, 0],
#  'doc_8225': [0, 0.06908219097605246, 0],
#  'doc_8270': [0, 0.04945656853967392, 0],
#  'doc_8275': [0, 0.24634969989573424, 0],
#  'doc_8277': [0, 0.07253630052485509, 0],
#  'doc_8289': [0, 0.05579715424988852, 0],
#  'doc_8293': [0, 0.10362328646407869, 0],
#  'doc_8306': [0, 0.03509820993138149, 0],
#  'doc_8316': [0, 0.11762643328354878, 0],
#  'doc_8317': [0, 0.07503755226709147, 0],
#  'doc_8319': [0, 0.03347829254993312, 0],
#  'doc_8332': [0, 0.07019641986276298, 0],
#  'doc_8340': [0, 0.0604469171040459, 0],
#  'doc_8346': [0, 0.1813407513121377, 0],
#  'doc_8351': [0, 0.12554359706224918, 0],
#  'doc_8353': [0, 0.032001309055083124, 0],
#  'doc_8354': [0, 0.03454109548802623, 0],
#  'doc_8355': [0, 0.04352178031491305, 0],
#  'doc_8364': [0, 0.11453100082871855, 0],
#  'doc_8367': [0, 0.07253630052485509, 0],
#  'doc_8374': [0, 0.0805958894720612, 0],
#  'doc_8379': [0, 0.12434794375689442, 0],
#  'doc_8380': [0, 0.12317484994786712, 0],
#  'doc_8382': [0, 0.04945656853967392, 0],
#  'doc_8387': [0, 0.16320667618092394, 0],
#  'doc_8389': [0, 0.402979447360306, 0],
#  'doc_8392': [0, 0.06217397187844721, 0],
#  'doc_8401': [0, 0.5440222539364131, 0],
#  'doc_8405': [0, 0.05726550041435927, 0],
#  'doc_8409': [0, 0.04730628295099244, 0],
#  'doc_8410': [0, 0.061298282133680354, 0],
#  'doc_8442': [0, 0.5440222539364131, 0],
#  'doc_8448': [0, 0.10121344259282104, 0],
#  'doc_8455': [0, 0.046299766292460694, 0],
#  'doc_8465': [0, 0.0604469171040459, 0],
#  'doc_8471': [0, 0.0659420913862319, 0],
#  'doc_8472': [0, 0.10615068369490988, 0],
#  'doc_8478': [0, 0.09259953258492139, 0],
#  'doc_8487': [0, 0.07019641986276298, 0],
#  'doc_8492': [0, 0.051403677537298874, 0],
#  'doc_8494': [0, 0.029809438571858252, 0],
#  'doc_8504': [0, 0.2417876684161836, 0],
#  'doc_8505': [0, 0.1978262741586957, 0],
#  'doc_8509': [0, 0.08618174319784762, 0],
#  'doc_8520': [0, 0.09067037565606885, 0],
#  'doc_8523': [0, 0.06800278174205164, 0],
#  'doc_8542': [0, 0.0604469171040459, 0],
#  'doc_8545': [0, 0.03454109548802623, 0],
#  'doc_8552': [0, 0.06800278174205164, 0],
#  'doc_8560': [0, 0.1934301347329469, 0],
#  'doc_8568': [0, 0.09281896275692357, 0],
#  'doc_8590': [0, 0.13322993973952973, 0],
#  'doc_8591': [0, 0.09326095781767083, 0],
#  'doc_8599': [0, 0.04317636936003279, 0],
#  'doc_8610': [0, 0.05828809863604426, 0],
#  'doc_8614': [0, 0.06400261811016625, 0],
#  'doc_8615': [0, 0.1813407513121377, 0],
#  'doc_8632': [0, 0.14039283972552596, 0],
#  'doc_8634': [0, 0.07376572934731025, 0],
#  'doc_8653': [0, 0.09259953258492139, 0],
#  'doc_8656': [0, 0.1673914627496656, 0],
#  'doc_8657': [0, 0.04440997991317658, 0],
#  'doc_8659': [0, 0.19200785433049877, 0],
#  'doc_8668': [0, 0.05579715424988852, 0],
#  'doc_8670': [0, 0.03567359042205988, 0],
#  'doc_8675': [0, 0.06800278174205164, 0],
#  'doc_8678': [0, 0.13600556348410328, 0],
#  'doc_8685': [0, 0.11453100082871855, 0],
#  'doc_8699': [0, 0.11762643328354878, 0],
#  'doc_8704': [0, 0.08211656663191141, 0],
#  'doc_8709': [0, 0.05440222539364131, 0],
#  'doc_8711': [0, 0.08881995982635316, 0],
#  'doc_8713': [0, 0.04730628295099244, 0],
#  'doc_8718': [0, 0.10121344259282104, 0],
#  'doc_8723': [0, 0.07253630052485509, 0],
#  'doc_8744': [0, 0.1740871212596522, 0],
#  'doc_8745': [0, 0.037518776133545734, 0],
#  'doc_8752': [0, 0.10702077126617963, 0],
#  'doc_8755': [0, 0.07019641986276298, 0],
#  'doc_8763': [0, 0.05060672129641052, 0],
#  'doc_8771': [0, 0.06217397187844721, 0],
#  'doc_8772': [0, 0.015007510453418292, 0],
#  'doc_8774': [0, 0.13600556348410328, 0],
#  'doc_8780': [0, 0.09764501993730491, 0],
#  'doc_8783': [0, 0.1318841827724638, 0],
#  'doc_8796': [0, 0.2251126568012744, 0],
#  'doc_8798': [0, 0.1280052362203325, 0],
#  'doc_8812': [0, 0.06695658509986624, 0],
#  'doc_8818': [0, 0.1318841827724638, 0],
#  'doc_8822': [0, 0.22318861699955408, 0],
#  'doc_8830': [0, 0.05881321664177439, 0],
#  'doc_8831': [0, 0.10702077126617963, 0],
#  'doc_8835': [0, 0.03509820993138149, 0],
#  'doc_8864': [0, 0.1740871212596522, 0],
#  'doc_8874': [0, 0.05579715424988852, 0],
#  'doc_8885': [0, 0.1673914627496656, 0],
#  'doc_8886': [0, 0.03347829254993312, 0],
#  'doc_8893': [0, 0.026217939948742802, 0],
#  ...}

# %% [markdown]
# finding tfidfs of the query:

# %%
tfidf_query = []  
for word in final_query:
    tf_query = final_query.count(word) / len(final_query)
    idf_query = math.log( 18258 / len(inverted_index[vocabulary[word]]))
    tfidf_query.append(tf_query * idf_query)
tfidf_query
# Out:
# [2.172173917706899, 0.7253630052485508, 1.418510185808496]

# %% [markdown]
# finding denominator of our dear formula: norm of the query and norm of docs:

# %%
import numpy
norm_query = numpy.sqrt(sum(list(map(lambda x: x**2, tfidf_query))))

# %%
norm_doc = {}
for i in range(18259):
    doc = 'doc_'+ str(i)
    nomin = 0
    for i in inverted_query:
        for j in inverted_query[i]:
            if j[0] == doc :
                nomin = nomin + j[1]**2
                norm_doc[doc] = nomin
for i in norm_doc:
    norm_doc[i] = numpy.sqrt(norm_doc[i])

# %% [markdown]
# sorting them with haep algorithms:

# %%
daje= []
for i in n:
    st = i
    cos = numpy.dot(tfidf_query, n[st])
    cosine = round(cos / (norm_doc[st]*norm_query), 10)
    daje.append((cosine, i ))
    print('cosine for ' + i + ' whit words ['+ user_query + '] is:', cosine)
# Out:
# cosine for doc_1340 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_1344 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_2831 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_4026 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_4659 whit words [rare lake netflix] is: 0.820105581
# cosine for doc_6071 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_6186 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_6191 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_7522 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_8201 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_8628 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_9516 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_9707 whit words [rare lake netflix] is: 0.7602388465
# cosine for doc_10444 whit words [rare lake netflix] is: 0.7602388465
# cosine for doc_10446 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_11511 whit words [rare lake netflix] is: 0.7602388465
# cosine for doc_13279 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_13326 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_14448 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_14589 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_14722 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_15739 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_16079 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_16867 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_16912 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_17487 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_17489 whit words [rare lake netflix] is: 0.806354738
# cosine for doc_5 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_19 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_58 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_61 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_72 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_90 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_97 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_98 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_100 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_103 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_136 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_143 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_151 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_153 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_177 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_179 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_180 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_181 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_182 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_186 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_192 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_194 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_202 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_204 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_218 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_219 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_225 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_226 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_231 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_233 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_241 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_244 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_247 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_255 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_261 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_262 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_267 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_270 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_276 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_295 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_298 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_301 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_304 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_308 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_310 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_311 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_316 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_329 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_355 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_356 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_374 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_375 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_381 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_383 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_398 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_403 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_435 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_441 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_443 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_444 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_458 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_463 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_475 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_482 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_485 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_495 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_507 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_519 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_527 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_543 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_554 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_558 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_566 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_570 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_585 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_621 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_628 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_654 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_658 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_669 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_672 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_673 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_678 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_680 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_693 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_701 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_720 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_740 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_758 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_760 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_764 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_768 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_777 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_778 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_781 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_830 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_847 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_853 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_856 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_860 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_861 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_862 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_896 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_901 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_904 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_907 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_937 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_941 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_981 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_984 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1001 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1003 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1006 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1012 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1046 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1048 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1052 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1053 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1055 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1066 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1068 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1084 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1096 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1104 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1127 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1134 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1147 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1152 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1160 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1178 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1183 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1192 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1208 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1258 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1266 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1270 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1308 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1313 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1317 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1333 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1339 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1345 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1360 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1366 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1370 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1372 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1395 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1402 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1409 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1475 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1479 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1510 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1512 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1514 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1518 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1520 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1556 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1561 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1565 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1576 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1595 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1599 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1609 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1613 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1624 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1635 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1639 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1640 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1647 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1664 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1690 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1705 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1723 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1724 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1729 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1731 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1733 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1736 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1737 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1741 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1764 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1771 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1774 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1775 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1783 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1789 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1803 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1804 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1808 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1830 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1837 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1853 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1861 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1865 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1867 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1872 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1883 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1889 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1903 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1907 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1918 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1939 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1942 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1945 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1950 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1953 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1966 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1969 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_1998 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2003 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2012 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2020 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2031 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2040 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2048 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2051 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2083 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2085 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2095 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2101 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2111 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2118 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2130 whit words [rare lake netflix] is: 0.5606719505
# cosine for doc_2147 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2152 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2157 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2178 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2181 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2189 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2207 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2222 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2224 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2237 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2238 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2245 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2272 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2279 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2280 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2282 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2287 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2295 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2302 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2303 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2329 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2337 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2339 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2359 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2365 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2368 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2372 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2376 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2377 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2380 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2389 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2410 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2424 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2427 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2436 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2442 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2449 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2464 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2468 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2481 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2494 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2495 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2532 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2545 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2553 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2554 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2561 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2590 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2593 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2611 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2663 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2665 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2668 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2670 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2673 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2702 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2714 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2723 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2730 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2734 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2736 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2740 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2751 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2777 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2782 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2789 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2801 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2804 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2813 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2816 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2841 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2843 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2844 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2858 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2867 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2870 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2872 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2889 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2908 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2929 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2946 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2957 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2959 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2960 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2967 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_2983 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3004 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3011 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3014 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3016 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3029 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3056 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3082 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3083 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3092 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3119 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3128 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3141 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3142 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3145 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3159 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3171 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3173 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3181 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3188 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3193 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3197 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3198 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3201 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3204 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3215 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3218 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3226 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3238 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3243 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3252 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3262 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3276 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3279 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3305 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3326 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3327 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3329 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3343 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3345 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3353 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3365 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3378 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3379 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3383 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3396 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3401 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3403 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3420 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3424 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3429 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3432 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3433 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3450 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3478 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3493 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3496 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3499 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3500 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3505 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3507 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3518 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3526 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3543 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3589 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3618 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3621 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3652 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3665 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3712 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3715 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3722 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3754 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3767 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3769 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3772 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3776 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3794 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3814 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3815 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3841 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3846 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3859 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3867 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3868 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3880 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3884 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3886 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3887 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3889 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3919 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3925 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3926 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3936 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3945 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3948 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3955 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3961 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3963 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3971 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3990 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_3997 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4014 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4021 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4042 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4060 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4065 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4079 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4083 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4088 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4111 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4147 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4152 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4162 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4177 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4178 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4184 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4185 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4192 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4217 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4220 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4232 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4263 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4266 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4277 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4279 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4291 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4322 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4335 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4344 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4347 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4362 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4374 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4378 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4380 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4381 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4389 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4401 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4423 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4426 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4436 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4443 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4450 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4462 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4463 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4465 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4474 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4489 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4494 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4505 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4520 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4521 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4526 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4531 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4539 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4551 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4556 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4574 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4580 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4590 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4600 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4606 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4617 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4624 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4627 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4629 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4641 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4643 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4647 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4650 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4655 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4670 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4674 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4677 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4691 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4701 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4724 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4731 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4746 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4749 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4801 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4829 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4836 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4840 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4842 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4850 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4854 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4861 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4867 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4876 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4877 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4879 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4900 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4906 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4916 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4920 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4926 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4927 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4937 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4948 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4955 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4964 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4968 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4974 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4977 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_4993 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5028 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5034 whit words [rare lake netflix] is: 0.5914321909
# cosine for doc_5041 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5051 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5073 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5076 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5082 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5084 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5125 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5129 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5143 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5155 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5160 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5163 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5168 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5174 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5177 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5183 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5197 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5208 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5226 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5233 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5244 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5261 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5272 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5276 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5281 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5284 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5295 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5300 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5307 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5311 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5315 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5325 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5329 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5333 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5341 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5359 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5367 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5372 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5374 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5375 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5386 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5389 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5399 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5402 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5406 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5417 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5421 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5430 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5445 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5452 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5454 whit words [rare lake netflix] is: 0.5914321909
# cosine for doc_5461 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5464 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5471 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5474 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5500 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5503 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5509 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5516 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5521 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5523 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5531 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5551 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5557 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5562 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5568 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5573 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5578 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5581 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5585 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5587 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5590 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5606 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5618 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5627 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5641 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5642 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5645 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5649 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5650 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5651 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5655 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5660 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5664 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5666 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5693 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5694 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5697 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5700 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5703 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5709 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5720 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5721 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5727 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5735 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5737 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5748 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5763 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5769 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5778 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5779 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5781 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5805 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5806 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5808 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5827 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5828 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5834 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5842 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5849 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5857 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5858 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5863 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5870 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5875 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5876 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5887 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5890 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5894 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5899 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5917 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5941 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5946 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5953 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5954 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5956 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5958 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5967 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_5974 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6002 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6007 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6014 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6018 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6031 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6042 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6049 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6062 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6063 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6114 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6117 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6131 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6132 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6140 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6146 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6151 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6152 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6164 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6179 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6190 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6195 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6196 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6199 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6200 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6214 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6216 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6219 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6231 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6241 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6249 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6268 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6269 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6277 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6282 whit words [rare lake netflix] is: 0.2692693671
# cosine for doc_6284 whit words [rare lake netflix] is: 0.2692693671
# ...
# cosine for doc_744 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_837 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_845 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_902 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_970 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1087 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1089 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1193 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1218 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1231 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1242 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1294 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1325 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1327 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1361 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1464 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1474 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1663 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1671 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1777 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1859 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_1977 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2184 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2333 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2381 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2460 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2580 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2598 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2609 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2639 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2691 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2856 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2880 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_2974 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_3095 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_3230 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_3386 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_3454 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_3668 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_3766 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_3994 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4089 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4180 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4189 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4230 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4284 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4301 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4379 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4384 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4430 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4456 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4543 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4548 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4569 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4662 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_4738 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5090 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5121 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5135 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5298 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5335 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5419 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5432 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5685 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5702 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5768 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5844 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5852 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5888 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_5918 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6162 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6234 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6436 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6463 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6683 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6726 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6742 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6781 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6815 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6873 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6911 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_6957 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7040 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7053 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7204 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7300 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7367 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7439 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7591 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7737 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7808 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7859 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_7952 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_8143 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_8179 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_8255 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_8294 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_8303 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_8360 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_8424 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_8695 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9132 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9344 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9377 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9709 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9711 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9776 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9784 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9875 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9959 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9966 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_9967 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10090 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10206 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10238 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10321 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10323 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10324 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10589 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10626 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10830 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_10920 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11047 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11223 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11317 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11328 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11404 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11435 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11553 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11560 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11567 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11590 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11607 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11630 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11642 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11714 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11791 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11821 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_11853 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12004 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12188 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12284 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12325 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12361 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12376 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12508 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12581 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12591 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12628 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12635 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12724 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12770 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12898 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12924 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12947 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12972 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12978 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_12983 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13062 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13066 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13130 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13132 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13223 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13342 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13406 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13590 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13602 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13652 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13741 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13774 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13822 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13904 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_13994 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14023 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14031 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14040 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14046 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14360 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14374 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14410 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14473 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14635 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14676 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14740 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14935 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14942 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_14991 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15002 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15128 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15188 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15224 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15267 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15287 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15295 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15381 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15516 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15832 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_15904 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16043 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16297 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16317 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16336 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16582 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16618 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16646 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16652 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16673 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16811 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16875 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16879 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_16908 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17031 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17039 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17057 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17064 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17175 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17198 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17208 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17221 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17304 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17332 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17339 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17432 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17502 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17511 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17525 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17578 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17622 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17739 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17894 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17925 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_17976 whit words [rare lake netflix] is: 0.5265795708
# cosine for doc_18146 whit words [rare lake netflix] is: 0.5265795708

# %%
import heapq

heap = []
for i in daje:
    heapq.heappush(heap, i)

heapq.nlargest(10, heap)
# Out:
# [(0.820105581, 'doc_4659'),
#  (0.806354738, 'doc_9516'),
#  (0.806354738, 'doc_8628'),
#  (0.806354738, 'doc_8201'),
#  (0.806354738, 'doc_7522'),
#  (0.806354738, 'doc_6191'),
#  (0.806354738, 'doc_6186'),
#  (0.806354738, 'doc_6071'),
#  (0.806354738, 'doc_4026'),
#  (0.806354738, 'doc_2831')]
